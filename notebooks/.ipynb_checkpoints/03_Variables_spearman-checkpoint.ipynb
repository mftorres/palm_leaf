# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from matplotlib import gridspec
import scipy.stats as stats
from scipy.stats import gaussian_kde
import seaborn as sns
from matplotlib import rcParams 
# from matplotlib import style
from matplotlib.colors import ListedColormap # control color in seaborn heatmap
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
import matplotlib.patheffects as path_effects
import itertools

from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
palms=pd.read_csv('../data_files/palms_alltraits_curated_20220620.csv',sep='\t')
palms.groupby(by='shape').count()['species']
# Out:
# shape
# bipinnate       14
# cospalmate     442
# entire         105
# pinnate       1298
# variable       139
# Name: species, dtype: int64

# %%
list(palms.columns)
palms['UnderstoreyCanopy'].unique()
palms['UnderstoreyCanopy'].replace('canopy',1,inplace=True)
palms['UnderstoreyCanopy'].replace('understorey',0,inplace=True)
palms['UnderstoreyCanopy'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
vars_test=['CHELSA_ai_stand','CHELSA_bio10_stand','CHELSA_bio11_stand','CHELSA_bio12_stand','CHELSA_bio13_stand','CHELSA_bio14_stand',
'CHELSA_bio15_stand','CHELSA_bio16_stand','CHELSA_bio17_stand','CHELSA_bio18_stand','CHELSA_bio19_stand','CHELSA_bio1_stand',
'CHELSA_bio2_stand','CHELSA_bio3_stand','CHELSA_bio4_stand','CHELSA_bio5_stand','CHELSA_bio6_stand','CHELSA_bio7_stand',
'CHELSA_bio8_stand','CHELSA_bio9_stand','CHELSA_cmi_max_stand','CHELSA_cmi_mean_stand','CHELSA_cmi_min_stand',
 'CHELSA_cmi_range_stand','CHELSA_fcf_stand','CHELSA_gdd0_stand','CHELSA_gdgfgd0_stand','CHELSA_gsl_stand',
'CHELSA_gst_stand','CHELSA_hurs_max_stand','CHELSA_hurs_min_stand','CHELSA_hurs_range_stand','CHELSA_lgd_stand',
'CHELSA_ngd0_stand','CHELSA_npp_stand','CHELSA_vpd_max_stand','CHELSA_vpd_mean_stand','CHELSA_vpd_min_stand',
'Simard_Pinto_3DGlobalVeg_JGR_stand','MaxStemHeight_m_stand','MaxStemDia_cm_stand','MaxLeafNumber_stand',
'Max_Blade_Length_m_stand','Max_Rachis_Length_m_stand','Max_Petiole_length_m_stand','StemHeightBladeLength_stand',
'HeightOverCanopy_stand','UnderstoreyCanopy']

all_variables=palms[vars_test]
np.random.seed(666)
all_rho, all_pval=stats.spearmanr(all_variables,axis=0,nan_policy='omit')
print(all_pval)

# %%
fig,ax=plt.subplots(figsize=(27,25),facecolor='w')

hm=sns.heatmap(all_rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=vars_test,
               yticklabels=vars_test,ax=ax,cbar=False,
           annot=True,fmt='.1f',annot_kws={'fontsize':15,'color':'#e3e3e3','fontweight':'bold'})
sns.heatmap(all_rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=vars_test,yticklabels=vars_test,ax=ax,cbar=False,
           annot=True,mask=all_rho<0.6,fmt='.1f',annot_kws={'fontsize':15,'color':'#787878','fontweight':'bold'})
hm.set_xticklabels(hm.get_xticklabels(), rotation=90,fontdict={'fontsize':18,'verticalalignment':'top'}) #horizontalalignment
hm.set_yticklabels(hm.get_yticklabels(), rotation=0,fontdict={'fontsize':18,'verticalalignment':'center'}) #[ 'center' | 'top' | 'bottom' | 'baseline' ]

# for tick,color in zip(ax.get_xticklabels(),allvariable_coldict.values()):
#     tick.set_color(color)
# for tick,color in zip(ax.get_yticklabels(),allvariable_coldict.values()):
#     tick.set_color(color)

# plt.savefig('./Cor_allvariables.pdf',dpi=300,bbox_inches='tight')
plt.show()

# %%
rhopd=pd.DataFrame(all_rho, columns=vars_test, index=vars_test)

cor_vars={}
for col in rhopd.columns:
    correlates=[]
    for index,row in rhopd[col].items():
        if row == 1:
            pass
        elif 0.7 <= row:
            print('%s is correlated with %s, coefficient %.2f'%(col, index, row))
            correlates.append(index)
        elif -0.7 >= row:
            print('%s is correlated with %s, coefficient %.2f'%(col, index, row))
            correlates.append(index)
    cor_vars[col]=correlates
cor_vars
# Out:
# CHELSA_ai_stand is correlated with CHELSA_bio2_stand, coefficient 0.77
# CHELSA_ai_stand is correlated with CHELSA_bio7_stand, coefficient 0.74
# CHELSA_ai_stand is correlated with CHELSA_cmi_max_stand, coefficient -0.89
# CHELSA_ai_stand is correlated with CHELSA_cmi_mean_stand, coefficient -0.89
# CHELSA_ai_stand is correlated with CHELSA_cmi_min_stand, coefficient -0.89
# CHELSA_ai_stand is correlated with CHELSA_cmi_range_stand, coefficient -0.90
# CHELSA_bio10_stand is correlated with CHELSA_bio11_stand, coefficient 0.72
# CHELSA_bio10_stand is correlated with CHELSA_bio1_stand, coefficient 0.92
# CHELSA_bio10_stand is correlated with CHELSA_bio5_stand, coefficient 0.85
# CHELSA_bio10_stand is correlated with CHELSA_bio8_stand, coefficient 0.84
# CHELSA_bio10_stand is correlated with CHELSA_bio9_stand, coefficient 0.88
# CHELSA_bio10_stand is correlated with CHELSA_gdd0_stand, coefficient 0.92
# CHELSA_bio10_stand is correlated with CHELSA_gst_stand, coefficient 0.90
# CHELSA_bio10_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.91
# CHELSA_bio10_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.94
# CHELSA_bio10_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.80
# CHELSA_bio11_stand is correlated with CHELSA_bio10_stand, coefficient 0.72
# CHELSA_bio11_stand is correlated with CHELSA_bio1_stand, coefficient 0.88
# CHELSA_bio11_stand is correlated with CHELSA_bio6_stand, coefficient 0.94
# CHELSA_bio11_stand is correlated with CHELSA_bio8_stand, coefficient 0.86
# CHELSA_bio11_stand is correlated with CHELSA_bio9_stand, coefficient 0.83
# CHELSA_bio11_stand is correlated with CHELSA_gdd0_stand, coefficient 0.88
# CHELSA_bio11_stand is correlated with CHELSA_gst_stand, coefficient 0.90
# CHELSA_bio11_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.82
# CHELSA_bio12_stand is correlated with CHELSA_bio13_stand, coefficient 0.95
# CHELSA_bio12_stand is correlated with CHELSA_bio14_stand, coefficient 0.89
# CHELSA_bio12_stand is correlated with CHELSA_bio16_stand, coefficient 0.96
# CHELSA_bio12_stand is correlated with CHELSA_bio17_stand, coefficient 0.92
# CHELSA_bio12_stand is correlated with CHELSA_bio18_stand, coefficient 0.93
# CHELSA_bio12_stand is correlated with CHELSA_bio19_stand, coefficient 0.90
# CHELSA_bio12_stand is correlated with CHELSA_bio3_stand, coefficient 0.71
# CHELSA_bio12_stand is correlated with CHELSA_bio4_stand, coefficient -0.86
# CHELSA_bio12_stand is correlated with CHELSA_gsl_stand, coefficient 0.78
# CHELSA_bio12_stand is correlated with CHELSA_hurs_min_stand, coefficient 0.73
# CHELSA_bio12_stand is correlated with CHELSA_npp_stand, coefficient 0.98
# CHELSA_bio13_stand is correlated with CHELSA_bio12_stand, coefficient 0.95
# CHELSA_bio13_stand is correlated with CHELSA_bio14_stand, coefficient 0.74
# CHELSA_bio13_stand is correlated with CHELSA_bio16_stand, coefficient 1.00
# CHELSA_bio13_stand is correlated with CHELSA_bio17_stand, coefficient 0.78
# CHELSA_bio13_stand is correlated with CHELSA_bio18_stand, coefficient 0.89
# CHELSA_bio13_stand is correlated with CHELSA_bio19_stand, coefficient 0.80
# CHELSA_bio13_stand is correlated with CHELSA_bio4_stand, coefficient -0.80
# CHELSA_bio13_stand is correlated with CHELSA_gsl_stand, coefficient 0.73
# CHELSA_bio13_stand is correlated with CHELSA_hurs_max_stand, coefficient 0.71
# CHELSA_bio13_stand is correlated with CHELSA_npp_stand, coefficient 0.93
# CHELSA_bio14_stand is correlated with CHELSA_bio12_stand, coefficient 0.89
# CHELSA_bio14_stand is correlated with CHELSA_bio13_stand, coefficient 0.74
# CHELSA_bio14_stand is correlated with CHELSA_bio16_stand, coefficient 0.78
# CHELSA_bio14_stand is correlated with CHELSA_bio17_stand, coefficient 0.99
# CHELSA_bio14_stand is correlated with CHELSA_bio18_stand, coefficient 0.83
# CHELSA_bio14_stand is correlated with CHELSA_bio19_stand, coefficient 0.91
# CHELSA_bio14_stand is correlated with CHELSA_bio4_stand, coefficient -0.78
# CHELSA_bio14_stand is correlated with CHELSA_gsl_stand, coefficient 0.78
# CHELSA_bio14_stand is correlated with CHELSA_hurs_min_stand, coefficient 0.78
# CHELSA_bio14_stand is correlated with CHELSA_lgd_stand, coefficient -0.72
# CHELSA_bio14_stand is correlated with CHELSA_npp_stand, coefficient 0.88
# CHELSA_bio15_stand is correlated with CHELSA_hurs_range_stand, coefficient 0.77
# CHELSA_bio16_stand is correlated with CHELSA_bio12_stand, coefficient 0.96
# CHELSA_bio16_stand is correlated with CHELSA_bio13_stand, coefficient 1.00
# CHELSA_bio16_stand is correlated with CHELSA_bio14_stand, coefficient 0.78
# CHELSA_bio16_stand is correlated with CHELSA_bio17_stand, coefficient 0.81
# CHELSA_bio16_stand is correlated with CHELSA_bio18_stand, coefficient 0.90
# CHELSA_bio16_stand is correlated with CHELSA_bio19_stand, coefficient 0.83
# CHELSA_bio16_stand is correlated with CHELSA_bio4_stand, coefficient -0.81
# CHELSA_bio16_stand is correlated with CHELSA_gsl_stand, coefficient 0.75
# CHELSA_bio16_stand is correlated with CHELSA_hurs_max_stand, coefficient 0.71
# CHELSA_bio16_stand is correlated with CHELSA_npp_stand, coefficient 0.94
# CHELSA_bio17_stand is correlated with CHELSA_bio12_stand, coefficient 0.92
# CHELSA_bio17_stand is correlated with CHELSA_bio13_stand, coefficient 0.78
# CHELSA_bio17_stand is correlated with CHELSA_bio14_stand, coefficient 0.99
# CHELSA_bio17_stand is correlated with CHELSA_bio16_stand, coefficient 0.81
# CHELSA_bio17_stand is correlated with CHELSA_bio18_stand, coefficient 0.85
# CHELSA_bio17_stand is correlated with CHELSA_bio19_stand, coefficient 0.93
# CHELSA_bio17_stand is correlated with CHELSA_bio4_stand, coefficient -0.80
# CHELSA_bio17_stand is correlated with CHELSA_gsl_stand, coefficient 0.79
# CHELSA_bio17_stand is correlated with CHELSA_hurs_min_stand, coefficient 0.78
# CHELSA_bio17_stand is correlated with CHELSA_lgd_stand, coefficient -0.72
# CHELSA_bio17_stand is correlated with CHELSA_npp_stand, coefficient 0.90
# CHELSA_bio18_stand is correlated with CHELSA_bio12_stand, coefficient 0.93
# CHELSA_bio18_stand is correlated with CHELSA_bio13_stand, coefficient 0.89
# CHELSA_bio18_stand is correlated with CHELSA_bio14_stand, coefficient 0.83
# CHELSA_bio18_stand is correlated with CHELSA_bio16_stand, coefficient 0.90
# CHELSA_bio18_stand is correlated with CHELSA_bio17_stand, coefficient 0.85
# CHELSA_bio18_stand is correlated with CHELSA_bio19_stand, coefficient 0.75
# CHELSA_bio18_stand is correlated with CHELSA_bio4_stand, coefficient -0.81
# CHELSA_bio18_stand is correlated with CHELSA_gsl_stand, coefficient 0.79
# CHELSA_bio18_stand is correlated with CHELSA_hurs_min_stand, coefficient 0.72
# CHELSA_bio18_stand is correlated with CHELSA_lgd_stand, coefficient -0.70
# CHELSA_bio18_stand is correlated with CHELSA_npp_stand, coefficient 0.90
# CHELSA_bio19_stand is correlated with CHELSA_bio12_stand, coefficient 0.90
# CHELSA_bio19_stand is correlated with CHELSA_bio13_stand, coefficient 0.80
# CHELSA_bio19_stand is correlated with CHELSA_bio14_stand, coefficient 0.91
# CHELSA_bio19_stand is correlated with CHELSA_bio16_stand, coefficient 0.83
# CHELSA_bio19_stand is correlated with CHELSA_bio17_stand, coefficient 0.93
# CHELSA_bio19_stand is correlated with CHELSA_bio18_stand, coefficient 0.75
# CHELSA_bio19_stand is correlated with CHELSA_bio4_stand, coefficient -0.76
# CHELSA_bio19_stand is correlated with CHELSA_gsl_stand, coefficient 0.75
# CHELSA_bio19_stand is correlated with CHELSA_npp_stand, coefficient 0.89
# CHELSA_bio1_stand is correlated with CHELSA_bio10_stand, coefficient 0.92
# CHELSA_bio1_stand is correlated with CHELSA_bio11_stand, coefficient 0.88
# CHELSA_bio1_stand is correlated with CHELSA_bio5_stand, coefficient 0.76
# CHELSA_bio1_stand is correlated with CHELSA_bio6_stand, coefficient 0.76
# CHELSA_bio1_stand is correlated with CHELSA_bio8_stand, coefficient 0.88
# CHELSA_bio1_stand is correlated with CHELSA_bio9_stand, coefficient 0.91
# CHELSA_bio1_stand is correlated with CHELSA_gdd0_stand, coefficient 1.00
# CHELSA_bio1_stand is correlated with CHELSA_gst_stand, coefficient 0.97
# CHELSA_bio1_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.78
# CHELSA_bio1_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.85
# CHELSA_bio1_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.86
# CHELSA_bio2_stand is correlated with CHELSA_ai_stand, coefficient 0.77
# CHELSA_bio2_stand is correlated with CHELSA_bio3_stand, coefficient 0.77
# CHELSA_bio2_stand is correlated with CHELSA_cmi_max_stand, coefficient -0.85
# CHELSA_bio2_stand is correlated with CHELSA_cmi_mean_stand, coefficient -0.85
# CHELSA_bio2_stand is correlated with CHELSA_cmi_min_stand, coefficient -0.85
# CHELSA_bio2_stand is correlated with CHELSA_cmi_range_stand, coefficient -0.84
# CHELSA_bio3_stand is correlated with CHELSA_bio12_stand, coefficient 0.71
# CHELSA_bio3_stand is correlated with CHELSA_bio2_stand, coefficient 0.77
# CHELSA_bio4_stand is correlated with CHELSA_bio12_stand, coefficient -0.86
# CHELSA_bio4_stand is correlated with CHELSA_bio13_stand, coefficient -0.80
# CHELSA_bio4_stand is correlated with CHELSA_bio14_stand, coefficient -0.78
# CHELSA_bio4_stand is correlated with CHELSA_bio16_stand, coefficient -0.81
# CHELSA_bio4_stand is correlated with CHELSA_bio17_stand, coefficient -0.80
# CHELSA_bio4_stand is correlated with CHELSA_bio18_stand, coefficient -0.81
# CHELSA_bio4_stand is correlated with CHELSA_bio19_stand, coefficient -0.76
# CHELSA_bio4_stand is correlated with CHELSA_gsl_stand, coefficient -0.72
# CHELSA_bio4_stand is correlated with CHELSA_hurs_min_stand, coefficient -0.74
# CHELSA_bio4_stand is correlated with CHELSA_npp_stand, coefficient -0.86
# CHELSA_bio5_stand is correlated with CHELSA_bio10_stand, coefficient 0.85
# CHELSA_bio5_stand is correlated with CHELSA_bio1_stand, coefficient 0.76
# CHELSA_bio5_stand is correlated with CHELSA_bio9_stand, coefficient 0.79
# CHELSA_bio5_stand is correlated with CHELSA_gdd0_stand, coefficient 0.76
# CHELSA_bio5_stand is correlated with CHELSA_gst_stand, coefficient 0.73
# CHELSA_bio5_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.79
# CHELSA_bio5_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.75
# CHELSA_bio6_stand is correlated with CHELSA_bio11_stand, coefficient 0.94
# CHELSA_bio6_stand is correlated with CHELSA_bio1_stand, coefficient 0.76
# CHELSA_bio6_stand is correlated with CHELSA_bio7_stand, coefficient -0.78
# CHELSA_bio6_stand is correlated with CHELSA_bio8_stand, coefficient 0.78
# CHELSA_bio6_stand is correlated with CHELSA_gdd0_stand, coefficient 0.76
# CHELSA_bio6_stand is correlated with CHELSA_gst_stand, coefficient 0.78
# CHELSA_bio6_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.79
# CHELSA_bio7_stand is correlated with CHELSA_ai_stand, coefficient 0.74
# CHELSA_bio7_stand is correlated with CHELSA_bio6_stand, coefficient -0.78
# CHELSA_bio7_stand is correlated with CHELSA_cmi_max_stand, coefficient -0.82
# CHELSA_bio7_stand is correlated with CHELSA_cmi_mean_stand, coefficient -0.83
# CHELSA_bio7_stand is correlated with CHELSA_cmi_min_stand, coefficient -0.83
# CHELSA_bio7_stand is correlated with CHELSA_cmi_range_stand, coefficient -0.81
# CHELSA_bio8_stand is correlated with CHELSA_bio10_stand, coefficient 0.84
# CHELSA_bio8_stand is correlated with CHELSA_bio11_stand, coefficient 0.86
# CHELSA_bio8_stand is correlated with CHELSA_bio1_stand, coefficient 0.88
# CHELSA_bio8_stand is correlated with CHELSA_bio6_stand, coefficient 0.78
# CHELSA_bio8_stand is correlated with CHELSA_bio9_stand, coefficient 0.76
# CHELSA_bio8_stand is correlated with CHELSA_gdd0_stand, coefficient 0.88
# CHELSA_bio8_stand is correlated with CHELSA_gst_stand, coefficient 0.92
# CHELSA_bio8_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.72
# CHELSA_bio8_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.80
# CHELSA_bio8_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.90
# CHELSA_bio9_stand is correlated with CHELSA_bio10_stand, coefficient 0.88
# CHELSA_bio9_stand is correlated with CHELSA_bio11_stand, coefficient 0.83
# CHELSA_bio9_stand is correlated with CHELSA_bio1_stand, coefficient 0.91
# CHELSA_bio9_stand is correlated with CHELSA_bio5_stand, coefficient 0.79
# CHELSA_bio9_stand is correlated with CHELSA_bio8_stand, coefficient 0.76
# CHELSA_bio9_stand is correlated with CHELSA_gdd0_stand, coefficient 0.91
# CHELSA_bio9_stand is correlated with CHELSA_gst_stand, coefficient 0.87
# CHELSA_bio9_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.76
# CHELSA_bio9_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.81
# CHELSA_bio9_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.75
# CHELSA_cmi_max_stand is correlated with CHELSA_ai_stand, coefficient -0.89
# CHELSA_cmi_max_stand is correlated with CHELSA_bio2_stand, coefficient -0.85
# CHELSA_cmi_max_stand is correlated with CHELSA_bio7_stand, coefficient -0.82
# CHELSA_cmi_max_stand is correlated with CHELSA_cmi_mean_stand, coefficient 1.00
# CHELSA_cmi_max_stand is correlated with CHELSA_cmi_min_stand, coefficient 0.99
# CHELSA_cmi_max_stand is correlated with CHELSA_cmi_range_stand, coefficient 0.99
# CHELSA_cmi_mean_stand is correlated with CHELSA_ai_stand, coefficient -0.89
# CHELSA_cmi_mean_stand is correlated with CHELSA_bio2_stand, coefficient -0.85
# CHELSA_cmi_mean_stand is correlated with CHELSA_bio7_stand, coefficient -0.83
# CHELSA_cmi_mean_stand is correlated with CHELSA_cmi_max_stand, coefficient 1.00
# CHELSA_cmi_mean_stand is correlated with CHELSA_cmi_min_stand, coefficient 1.00
# CHELSA_cmi_mean_stand is correlated with CHELSA_cmi_range_stand, coefficient 0.98
# CHELSA_cmi_min_stand is correlated with CHELSA_ai_stand, coefficient -0.89
# CHELSA_cmi_min_stand is correlated with CHELSA_bio2_stand, coefficient -0.85
# CHELSA_cmi_min_stand is correlated with CHELSA_bio7_stand, coefficient -0.83
# CHELSA_cmi_min_stand is correlated with CHELSA_cmi_max_stand, coefficient 0.99
# CHELSA_cmi_min_stand is correlated with CHELSA_cmi_mean_stand, coefficient 1.00
# CHELSA_cmi_min_stand is correlated with CHELSA_cmi_range_stand, coefficient 0.97
# CHELSA_cmi_range_stand is correlated with CHELSA_ai_stand, coefficient -0.90
# CHELSA_cmi_range_stand is correlated with CHELSA_bio2_stand, coefficient -0.84
# CHELSA_cmi_range_stand is correlated with CHELSA_bio7_stand, coefficient -0.81
# CHELSA_cmi_range_stand is correlated with CHELSA_cmi_max_stand, coefficient 0.99
# CHELSA_cmi_range_stand is correlated with CHELSA_cmi_mean_stand, coefficient 0.98
# CHELSA_cmi_range_stand is correlated with CHELSA_cmi_min_stand, coefficient 0.97
# CHELSA_gdd0_stand is correlated with CHELSA_bio10_stand, coefficient 0.92
# CHELSA_gdd0_stand is correlated with CHELSA_bio11_stand, coefficient 0.88
# CHELSA_gdd0_stand is correlated with CHELSA_bio1_stand, coefficient 1.00
# CHELSA_gdd0_stand is correlated with CHELSA_bio5_stand, coefficient 0.76
# CHELSA_gdd0_stand is correlated with CHELSA_bio6_stand, coefficient 0.76
# CHELSA_gdd0_stand is correlated with CHELSA_bio8_stand, coefficient 0.88
# CHELSA_gdd0_stand is correlated with CHELSA_bio9_stand, coefficient 0.91
# CHELSA_gdd0_stand is correlated with CHELSA_gst_stand, coefficient 0.97
# CHELSA_gdd0_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.78
# CHELSA_gdd0_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.85
# CHELSA_gdd0_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.86
# CHELSA_gdgfgd0_stand is correlated with CHELSA_ngd0_stand, coefficient -1.00
# CHELSA_gsl_stand is correlated with CHELSA_bio12_stand, coefficient 0.78
# CHELSA_gsl_stand is correlated with CHELSA_bio13_stand, coefficient 0.73
# CHELSA_gsl_stand is correlated with CHELSA_bio14_stand, coefficient 0.78
# CHELSA_gsl_stand is correlated with CHELSA_bio16_stand, coefficient 0.75
# CHELSA_gsl_stand is correlated with CHELSA_bio17_stand, coefficient 0.79
# CHELSA_gsl_stand is correlated with CHELSA_bio18_stand, coefficient 0.79
# CHELSA_gsl_stand is correlated with CHELSA_bio19_stand, coefficient 0.75
# CHELSA_gsl_stand is correlated with CHELSA_bio4_stand, coefficient -0.72
# CHELSA_gsl_stand is correlated with CHELSA_lgd_stand, coefficient -0.93
# CHELSA_gsl_stand is correlated with CHELSA_npp_stand, coefficient 0.78
# CHELSA_gst_stand is correlated with CHELSA_bio10_stand, coefficient 0.90
# CHELSA_gst_stand is correlated with CHELSA_bio11_stand, coefficient 0.90
# CHELSA_gst_stand is correlated with CHELSA_bio1_stand, coefficient 0.97
# CHELSA_gst_stand is correlated with CHELSA_bio5_stand, coefficient 0.73
# CHELSA_gst_stand is correlated with CHELSA_bio6_stand, coefficient 0.78
# CHELSA_gst_stand is correlated with CHELSA_bio8_stand, coefficient 0.92
# CHELSA_gst_stand is correlated with CHELSA_bio9_stand, coefficient 0.87
# CHELSA_gst_stand is correlated with CHELSA_gdd0_stand, coefficient 0.97
# CHELSA_gst_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.75
# CHELSA_gst_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.83
# CHELSA_gst_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.88
# CHELSA_hurs_max_stand is correlated with CHELSA_bio13_stand, coefficient 0.71
# CHELSA_hurs_max_stand is correlated with CHELSA_bio16_stand, coefficient 0.71
# CHELSA_hurs_max_stand is correlated with CHELSA_hurs_min_stand, coefficient 0.71
# CHELSA_hurs_min_stand is correlated with CHELSA_bio12_stand, coefficient 0.73
# CHELSA_hurs_min_stand is correlated with CHELSA_bio14_stand, coefficient 0.78
# CHELSA_hurs_min_stand is correlated with CHELSA_bio17_stand, coefficient 0.78
# CHELSA_hurs_min_stand is correlated with CHELSA_bio18_stand, coefficient 0.72
# CHELSA_hurs_min_stand is correlated with CHELSA_bio4_stand, coefficient -0.74
# CHELSA_hurs_min_stand is correlated with CHELSA_hurs_max_stand, coefficient 0.71
# CHELSA_hurs_range_stand is correlated with CHELSA_bio15_stand, coefficient 0.77
# CHELSA_lgd_stand is correlated with CHELSA_bio14_stand, coefficient -0.72
# CHELSA_lgd_stand is correlated with CHELSA_bio17_stand, coefficient -0.72
# CHELSA_lgd_stand is correlated with CHELSA_bio18_stand, coefficient -0.70
# CHELSA_lgd_stand is correlated with CHELSA_gsl_stand, coefficient -0.93
# CHELSA_ngd0_stand is correlated with CHELSA_gdgfgd0_stand, coefficient -1.00
# CHELSA_npp_stand is correlated with CHELSA_bio12_stand, coefficient 0.98
# CHELSA_npp_stand is correlated with CHELSA_bio13_stand, coefficient 0.93
# CHELSA_npp_stand is correlated with CHELSA_bio14_stand, coefficient 0.88
# CHELSA_npp_stand is correlated with CHELSA_bio16_stand, coefficient 0.94
# CHELSA_npp_stand is correlated with CHELSA_bio17_stand, coefficient 0.90
# CHELSA_npp_stand is correlated with CHELSA_bio18_stand, coefficient 0.90
# CHELSA_npp_stand is correlated with CHELSA_bio19_stand, coefficient 0.89
# CHELSA_npp_stand is correlated with CHELSA_bio4_stand, coefficient -0.86
# CHELSA_npp_stand is correlated with CHELSA_gsl_stand, coefficient 0.78
# CHELSA_vpd_max_stand is correlated with CHELSA_bio10_stand, coefficient 0.91
# CHELSA_vpd_max_stand is correlated with CHELSA_bio1_stand, coefficient 0.78
# CHELSA_vpd_max_stand is correlated with CHELSA_bio5_stand, coefficient 0.79
# CHELSA_vpd_max_stand is correlated with CHELSA_bio8_stand, coefficient 0.72
# CHELSA_vpd_max_stand is correlated with CHELSA_bio9_stand, coefficient 0.76
# CHELSA_vpd_max_stand is correlated with CHELSA_gdd0_stand, coefficient 0.78
# CHELSA_vpd_max_stand is correlated with CHELSA_gst_stand, coefficient 0.75
# CHELSA_vpd_max_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.94
# CHELSA_vpd_max_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.74
# CHELSA_vpd_mean_stand is correlated with CHELSA_bio10_stand, coefficient 0.94
# CHELSA_vpd_mean_stand is correlated with CHELSA_bio1_stand, coefficient 0.85
# CHELSA_vpd_mean_stand is correlated with CHELSA_bio5_stand, coefficient 0.75
# CHELSA_vpd_mean_stand is correlated with CHELSA_bio8_stand, coefficient 0.80
# CHELSA_vpd_mean_stand is correlated with CHELSA_bio9_stand, coefficient 0.81
# CHELSA_vpd_mean_stand is correlated with CHELSA_gdd0_stand, coefficient 0.85
# CHELSA_vpd_mean_stand is correlated with CHELSA_gst_stand, coefficient 0.83
# CHELSA_vpd_mean_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.94
# CHELSA_vpd_mean_stand is correlated with CHELSA_vpd_min_stand, coefficient 0.86
# CHELSA_vpd_min_stand is correlated with CHELSA_bio10_stand, coefficient 0.80
# CHELSA_vpd_min_stand is correlated with CHELSA_bio11_stand, coefficient 0.82
# CHELSA_vpd_min_stand is correlated with CHELSA_bio1_stand, coefficient 0.86
# CHELSA_vpd_min_stand is correlated with CHELSA_bio6_stand, coefficient 0.79
# CHELSA_vpd_min_stand is correlated with CHELSA_bio8_stand, coefficient 0.90
# CHELSA_vpd_min_stand is correlated with CHELSA_bio9_stand, coefficient 0.75
# CHELSA_vpd_min_stand is correlated with CHELSA_gdd0_stand, coefficient 0.86
# CHELSA_vpd_min_stand is correlated with CHELSA_gst_stand, coefficient 0.88
# CHELSA_vpd_min_stand is correlated with CHELSA_vpd_max_stand, coefficient 0.74
# CHELSA_vpd_min_stand is correlated with CHELSA_vpd_mean_stand, coefficient 0.86
# MaxStemHeight_m_stand is correlated with MaxStemDia_cm_stand, coefficient 0.75
# MaxStemHeight_m_stand is correlated with StemHeightBladeLength_stand, coefficient 0.94
# MaxStemHeight_m_stand is correlated with HeightOverCanopy_stand, coefficient 0.73
# MaxStemHeight_m_stand is correlated with UnderstoreyCanopy, coefficient 0.86
# MaxStemDia_cm_stand is correlated with MaxStemHeight_m_stand, coefficient 0.75
# MaxStemDia_cm_stand is correlated with Max_Rachis_Length_m_stand, coefficient 0.77
# MaxStemDia_cm_stand is correlated with StemHeightBladeLength_stand, coefficient 0.81
# MaxStemDia_cm_stand is correlated with UnderstoreyCanopy, coefficient 0.71
# Max_Blade_Length_m_stand is correlated with Max_Rachis_Length_m_stand, coefficient 0.90
# Max_Blade_Length_m_stand is correlated with StemHeightBladeLength_stand, coefficient 0.75
# Max_Rachis_Length_m_stand is correlated with MaxStemDia_cm_stand, coefficient 0.77
# Max_Rachis_Length_m_stand is correlated with Max_Blade_Length_m_stand, coefficient 0.90
# Max_Rachis_Length_m_stand is correlated with StemHeightBladeLength_stand, coefficient 0.77
# StemHeightBladeLength_stand is correlated with MaxStemHeight_m_stand, coefficient 0.94
# StemHeightBladeLength_stand is correlated with MaxStemDia_cm_stand, coefficient 0.81
# StemHeightBladeLength_stand is correlated with Max_Blade_Length_m_stand, coefficient 0.75
# StemHeightBladeLength_stand is correlated with Max_Rachis_Length_m_stand, coefficient 0.77
# StemHeightBladeLength_stand is correlated with HeightOverCanopy_stand, coefficient 0.73
# StemHeightBladeLength_stand is correlated with UnderstoreyCanopy, coefficient 0.83
# HeightOverCanopy_stand is correlated with MaxStemHeight_m_stand, coefficient 0.73
# HeightOverCanopy_stand is correlated with StemHeightBladeLength_stand, coefficient 0.73
# UnderstoreyCanopy is correlated with MaxStemHeight_m_stand, coefficient 0.86
# UnderstoreyCanopy is correlated with MaxStemDia_cm_stand, coefficient 0.71
# UnderstoreyCanopy is correlated with StemHeightBladeLength_stand, coefficient 0.83
# {'CHELSA_ai_stand': ['CHELSA_bio2_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_min_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_bio10_stand': ['CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_bio11_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_bio12_stand': ['CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio3_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_min_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio13_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_max_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio14_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_min_stand',
#   'CHELSA_lgd_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio15_stand': ['CHELSA_hurs_range_stand'],
#  'CHELSA_bio16_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_max_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio17_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_min_stand',
#   'CHELSA_lgd_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio18_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_min_stand',
#   'CHELSA_lgd_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio19_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio1_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_bio2_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio3_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_min_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_bio3_stand': ['CHELSA_bio12_stand', 'CHELSA_bio2_stand'],
#  'CHELSA_bio4_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_gsl_stand',
#   'CHELSA_hurs_min_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_bio5_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand'],
#  'CHELSA_bio6_stand': ['CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_bio7_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_min_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_bio8_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_bio9_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_cmi_max_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio2_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_min_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_cmi_mean_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio2_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_min_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_cmi_min_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio2_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_range_stand'],
#  'CHELSA_cmi_range_stand': ['CHELSA_ai_stand',
#   'CHELSA_bio2_stand',
#   'CHELSA_bio7_stand',
#   'CHELSA_cmi_max_stand',
#   'CHELSA_cmi_mean_stand',
#   'CHELSA_cmi_min_stand'],
#  'CHELSA_fcf_stand': [],
#  'CHELSA_gdd0_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_gdgfgd0_stand': ['CHELSA_ngd0_stand'],
#  'CHELSA_gsl_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_lgd_stand',
#   'CHELSA_npp_stand'],
#  'CHELSA_gst_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_hurs_max_stand': ['CHELSA_bio13_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_hurs_min_stand'],
#  'CHELSA_hurs_min_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_hurs_max_stand'],
#  'CHELSA_hurs_range_stand': ['CHELSA_bio15_stand'],
#  'CHELSA_lgd_stand': ['CHELSA_bio14_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_gsl_stand'],
#  'CHELSA_ngd0_stand': ['CHELSA_gdgfgd0_stand'],
#  'CHELSA_npp_stand': ['CHELSA_bio12_stand',
#   'CHELSA_bio13_stand',
#   'CHELSA_bio14_stand',
#   'CHELSA_bio16_stand',
#   'CHELSA_bio17_stand',
#   'CHELSA_bio18_stand',
#   'CHELSA_bio19_stand',
#   'CHELSA_bio4_stand',
#   'CHELSA_gsl_stand'],
#  'CHELSA_vpd_max_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_mean_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_vpd_mean_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio5_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_min_stand'],
#  'CHELSA_vpd_min_stand': ['CHELSA_bio10_stand',
#   'CHELSA_bio11_stand',
#   'CHELSA_bio1_stand',
#   'CHELSA_bio6_stand',
#   'CHELSA_bio8_stand',
#   'CHELSA_bio9_stand',
#   'CHELSA_gdd0_stand',
#   'CHELSA_gst_stand',
#   'CHELSA_vpd_max_stand',
#   'CHELSA_vpd_mean_stand'],
#  'Simard_Pinto_3DGlobalVeg_JGR_stand': [],
#  'MaxStemHeight_m_stand': ['MaxStemDia_cm_stand',
#   'StemHeightBladeLength_stand',
#   'HeightOverCanopy_stand',
#   'UnderstoreyCanopy'],
#  'MaxStemDia_cm_stand': ['MaxStemHeight_m_stand',
#   'Max_Rachis_Length_m_stand',
#   'StemHeightBladeLength_stand',
#   'UnderstoreyCanopy'],
#  'MaxLeafNumber_stand': [],
#  'Max_Blade_Length_m_stand': ['Max_Rachis_Length_m_stand',
#   'StemHeightBladeLength_stand'],
#  'Max_Rachis_Length_m_stand': ['MaxStemDia_cm_stand',
#   'Max_Blade_Length_m_stand',
#   'StemHeightBladeLength_stand'],
#  'Max_Petiole_length_m_stand': [],
#  'StemHeightBladeLength_stand': ['MaxStemHeight_m_stand',
#   'MaxStemDia_cm_stand',
#   'Max_Blade_Length_m_stand',
#   'Max_Rachis_Length_m_stand',
#   'HeightOverCanopy_stand',
#   'UnderstoreyCanopy'],
#  'HeightOverCanopy_stand': ['MaxStemHeight_m_stand',
#   'StemHeightBladeLength_stand'],
#  'UnderstoreyCanopy': ['MaxStemHeight_m_stand',
#   'MaxStemDia_cm_stand',
#   'StemHeightBladeLength_stand']}

# %% [markdown]
# **Variables that for our hypothesis should go:**
#
# - **Aridity (CHELSA_ai)** ~~mean annual air temperature (bio2) nor annual range of air temperature (bio7) climatic moisture index~~
#
# - **Plant height** ~~MaxStemHeight_m MaxStemDia_cm Max_Blade_Length_m UnderstoreyCanopy~~ Max_Rachis_Length_m HeightOverCanopy_stand
#
# - **HeightOverCanopy_stand**
#
# - **Rachis lenght** ~~MaxStemDia_cm Max_Blade_Length_m~~ StemHeightBladeLength
#
# - **Temperature bio1** (any) ~~mean daily maximum air temperture of the warmest month (bio5) mean daily minimum air temperature of the coldest month (bio6) annual range of air temperature (bio7) mean daily mean air tempertures of the wettest quarter (bio8) mean daily maximum air temperture of the warmest month (bio10) mean daily mean air tempertures of the driest quarter (bio9) mean daily mean air tempertures of the coldest quarter (bio11) Number of days above 0 (dgg0) Mean temperature of the growing season TREELIM (gst) vapour pressure deficit (vpd)~~
#
# - **Temperature seasonality** bio4 (any) Precipitation bio12 ~~precipitation amount of the wettest month (bio13) precipitation amount of the driest month (bio14) mean monthly precipitation amount of the wettest quarter (bio16) mean monthly precipitation amount of the driest quarter (bio17) mean monthyl precipitation amount of the warmest quarter (bio18) mean monthly precipitation amount of the warmest quarter (bio19) growing season length TREELIM (gsl) near-surface relative humidity (hurs) CHELSA_npp~~
#
# - **Precipitation bio12** (any) ~~isothermality (bio3) mean diurnal air temperature range (bio2) precipitation amount of the wettest month (bio13) precipitation amount of the driest month (bio14) mean monthly precipitation amount of the wettest quarter (bio16) mean monthly precipitation amount of the driest quarter (bio17) mean monthyl precipitation amount of the warmest quarter (bio18) mean monthly precipitation amount of the warmest quarter (bio19)~~ Temperature seasonality (bio4)
#
# - **Precipitation seasonality bio15** (any) ~~CHELSA_hurs_range~~

# %% [markdown]
# **Hypothesis 1a: temperature has a stronger effect on leaf shape than other variables (evaluating temp. seasonality instead of precipitation and plant height instead of canopy/understory proxy)**
#
# entire|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+plantHeight
# entire|palmate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+plantHeight
# palmate|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+plantHeight
#
# **Hypothesis 1b: temperature has a stronger effect on leaf shape than other variables (evaluating precipitation instead of temp. seasonality and plant height instead of canopy/understory proxy)**
#
# entire|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+plantHeight
# entire|palmate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+plantHeight
# palmate|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+plantHeight
#
# **Hypothesis 1c: temperature has a stronger effect on leaf shape than other variables (evaluating temp. seasonality instead of precipitation and canopy/understory instead of plant height)**
#
# entire|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+HeightOverCanopy
# entire|palmate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+HeightOverCanopy
# palmate|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+HeightOverCanopy
#
# **Hypothesis 1d: temperature has a stronger effect on leaf shape than other variables (evaluating precipitation instead of temp. seasonality and canopy/understory instead of plant height)**
#
# entire|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+HeightOverCanopy
# entire|palmate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+HeightOverCanopy
# palmate|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+HeightOverCanopy
#
# **Hypothesis 2a: rachis lenght and canopy/understory matter more than temperature (evaluating temp. seasonality instead of precipitation)**
#
# entire|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+RachisLength+HeightOverCanopy (could remove since it is more relevant for pinnate|palmate)
#
# entire|palmate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+RachisLength+HeightOverCanopy (could remove since it is more relevant for pinnate|palmate)
#
# palmate|pinnate\~AnnualMeanTemp+TempSeasonality+PrecSeasonality+RachisLength+HeightOverCanopy
#
# **Hypothesis 2b: rachis lenght and canopy/understory matter more than temperature (evaluating precipitation instead of temp. seasonality)**
#
# entire|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+RachisLength+HeightOverCanopy (could remove since it is more relevant for pinnate|palmate)
#
# entire|palmate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+RachisLength+HeightOverCanopy (could remove since it is more relevant for pinnate|palmate)
#
# palmate|pinnate\~AnnualMeanTemp+AnnualMeanPrecip+PrecSeasonality+RachisLength+HeightOverCanopy
# <!-- #### 18 x 3 = 54 -->

# %%
selected=['CHELSA_ai_stand','StemHeightBladeLength_stand','Max_Rachis_Length_m_stand','HeightOverCanopy'
          'CHELSA_bio1_stand','CHELSA_bio4_stand','CHELSA_bio12_stand','CHELSA_bio15_stand']

# %%
allvariable_dict={'CHELSA_ai_stand':'',
'CHELSA_bio10_stand':'',
'CHELSA_bio11_stand':'',
'CHELSA_bio12_stand':'',
'CHELSA_bio13_stand':'',
'CHELSA_bio14_stand':'',
'CHELSA_bio15_stand':'',
'CHELSA_bio16_stand':'',
'CHELSA_bio17_stand':'',
'CHELSA_bio18_stand':'',
'CHELSA_bio19_stand':'',
'CHELSA_bio1_stand':'',
'CHELSA_bio2_stand':'',
'CHELSA_bio3_stand':'',
'CHELSA_bio4_stand':'',
'CHELSA_bio5_stand':'',
'CHELSA_bio6_stand':'',
'CHELSA_bio7_stand':'',
'CHELSA_bio8_stand':'',
'CHELSA_bio9_stand':'',
'CHELSA_cmi_max_stand':'',
'CHELSA_cmi_mean_stand':'',
'CHELSA_cmi_min_stand':'',
'CHELSA_cmi_range_stand':'',
'CHELSA_fcf_stand':'',
'CHELSA_gdd0_stand':'',
'CHELSA_gdgfgd0_stand':'',
'CHELSA_gsl_stand':'',
'CHELSA_gst_stand':'',
'CHELSA_hurs_max_stand':'',
'CHELSA_hurs_min_stand':'',
'CHELSA_hurs_range_stand':'',
'CHELSA_lgd_stand':'',
'CHELSA_ngd0_stand':'',
'CHELSA_npp_stand':'',
'CHELSA_vpd_max_stand':'',
'CHELSA_vpd_mean_stand':'',
'CHELSA_vpd_min_stand':'',
'Simard_Pinto_3DGlobalVeg_JGR_stand':'',
'MaxStemHeight_m_stand':'',
'MaxStemDia_cm_stand':'',
'MaxLeafNumber_stand':'',
'Max_Blade_Length_m_stand':'',
'Max_Rachis_Length_m_stand':'',
'Max_Petiole_length_m_stand':'',
'StemHeightBladeLength_stand':'',
'HeightOverCanopy_stand':'',
'UnderstoreyCanopy':''}

allvariable_coldict={'bio1':'k','bio2':'#bababa','bio3':'#bababa','bio4':'k','bio5':'#bababa',
                  'bio6':'#bababa','bio7':'#bababa','bio8':'#bababa','bio9':'#bababa','bio10':'#bababa','bio11':'#bababa','bio12':'k',
                  'bio13':'#bababa','bio14':'#bababa','bio15':'k','bio16':'#bababa','bio17':'#bababa','bio18':'#bababa','bio19':'#bababa','nutrient_avail':'#bababa','aridity':'k',
                  'nutrient_retention':'#bababa', 'rooting_conditions':'#bababa', 'oxygen_avail_toroots':'#bababa', 'excess_salts':'#bababa', 'toxicity':'#bababa',
                  'workability':'#bababa','MaxStemHeight_m': '#bababa','MaxStemDia_cm':'#bababa','MaxLeafNumber':'k','Max_Blade_Length_m':'#bababa','Max_Rachis_Length_m':'#bababa',
                  'Max_Petiole_length_m':'#bababa','StemHeightBladeLength': 'k','UnderstoreyCanopy_num':'#bababa'}

# %%
fig,ax=plt.subplots(figsize=(27,25),facecolor='w')
hm=sns.heatmap(all_rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=allvariable_dict.values(),yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
           annot=True,fmt='.1f',annot_kws={'fontsize':15,'color':'#e3e3e3','fontweight':'bold'})
sns.heatmap(all_rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=allvariable_dict.values(),yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
           annot=True,mask=all_rho<0.6,fmt='.1f',annot_kws={'fontsize':15,'color':'#787878','fontweight':'bold'})
hm.set_xticklabels(hm.get_xticklabels(), rotation=90,fontdict={'fontsize':18,'verticalalignment':'top'}) #horizontalalignment
hm.set_yticklabels(hm.get_yticklabels(), rotation=0,fontdict={'fontsize':18,'verticalalignment':'center'}) #[ 'center' | 'top' | 'bottom' | 'baseline' ]

for tick,color in zip(ax.get_xticklabels(),allvariable_coldict.values()):
    tick.set_color(color)
for tick,color in zip(ax.get_yticklabels(),allvariable_coldict.values()):
    tick.set_color(color)

plt.savefig('./Cor_allvariables.pdf',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Variance inflation factor
#
# One recommendation is that if VIF is greater than 5, then the explanatory variable given by exog_idx is highly collinear with the other explanatory variables, and the parameter estimates will have large standard errors because of this.

# %%
selected=['CHELSA_ai_stand','StemHeightBladeLength_stand','Max_Rachis_Length_m_stand','HeightOverCanopy_stand',
          'CHELSA_bio1_stand','CHELSA_bio4_stand','CHELSA_bio12_stand','CHELSA_bio15_stand']

varselected=palms[selected]
varselected

vif=pd.DataFrame(columns=selected,index=selected+['Intercept'])
for col in varselected.columns:
    corrs=list(varselected.columns)
    corrs.remove(col)
    correlates = "+".join(corrs)
    y, X=dmatrices('%s ~'%(col) + correlates, varselected, return_type='dataframe')
    viflist=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    for index in range(len(viflist)):
#         print(viflist[index],list(X.columns)[index])
        vif.loc[list(X.columns)[index],col]=viflist[index]
vif
# Out:
#                             CHELSA_ai_stand StemHeightBladeLength_stand  \
# CHELSA_ai_stand                         NaN                    1.879162
# StemHeightBladeLength_stand        2.397802                         NaN
# Max_Rachis_Length_m_stand          2.428684                    1.101353
# HeightOverCanopy_stand             1.394778                    1.968186
# CHELSA_bio1_stand                  1.179147                    1.173132
# CHELSA_bio4_stand                  3.667125                    3.811835
# CHELSA_bio12_stand                 3.601739                    3.647729
# CHELSA_bio15_stand                 1.222443                    1.366409
# Intercept                           1.35473                    1.054891
#
#                             Max_Rachis_Length_m_stand HeightOverCanopy_stand  \
# CHELSA_ai_stand                              1.910528               1.289665
# StemHeightBladeLength_stand                  1.105498               2.322134
# Max_Rachis_Length_m_stand                         NaN                2.41093
# HeightOverCanopy_stand                       2.051138                    NaN
# CHELSA_bio1_stand                            1.175452               1.067176
# CHELSA_bio4_stand                            3.821888               3.763235
# CHELSA_bio12_stand                           3.630607               3.571187
# CHELSA_bio15_stand                           1.362918               1.362972
# Intercept                                    1.188433               1.366069
#
#                             CHELSA_bio1_stand CHELSA_bio4_stand  \
# CHELSA_ai_stand                        1.9099          1.833586
# StemHeightBladeLength_stand          2.424591          2.431974
# Max_Rachis_Length_m_stand            2.420277          2.429244
# HeightOverCanopy_stand               1.869419          2.035002
# CHELSA_bio1_stand                         NaN          1.160507
# CHELSA_bio4_stand                    3.759367               NaN
# CHELSA_bio12_stand                   3.646927          1.393088
# CHELSA_bio15_stand                   1.339955          1.290932
# Intercept                            1.367767          1.368619
#
#                             CHELSA_bio12_stand CHELSA_bio15_stand
# CHELSA_ai_stand                       1.886986           1.706551
# StemHeightBladeLength_stand            2.43853              2.434
# Max_Rachis_Length_m_stand             2.417983           2.418678
# HeightOverCanopy_stand                2.023471           2.057811
# CHELSA_bio1_stand                     1.179617           1.154884
# CHELSA_bio4_stand                     1.459686            3.60428
# CHELSA_bio12_stand                         NaN           3.636304
# CHELSA_bio15_stand                    1.364665                NaN
# Intercept                             1.366013           1.368323

# %% [markdown]
#  ### doing it for every hypothesis

# %%
hp1a=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio4_stand',
     'CHELSA_bio15_stand','StemHeightBladeLength_stand']
hp1b=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio12_stand',
     'CHELSA_bio15_stand','StemHeightBladeLength_stand']
hp1c=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio4_stand',
     'CHELSA_bio15_stand','HeightOverCanopy_stand']
hp1d=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio12_stand',
     'CHELSA_bio15_stand','HeightOverCanopy_stand']
hp2a=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio4_stand',
     'CHELSA_bio15_stand','Max_Rachis_Length_m_stand','HeightOverCanopy_stand']
hp2b=['CHELSA_ai_stand','CHELSA_bio1_stand','CHELSA_bio12_stand',
     'CHELSA_bio15_stand','Max_Rachis_Length_m_stand','HeightOverCanopy_stand']

# %%
for hyb in [hp1a,hp1b,hp1c,hp1d,hp2a,hp2b]:
    varselected=palms[hyb]

    vif=pd.DataFrame(columns=hyb,index=hyb+['Intercept'])
    for col in varselected.columns:
        corrs=list(varselected.columns)
        corrs.remove(col)
        correlates = "+".join(corrs)
        y, X=dmatrices('%s ~'%(col) + correlates, varselected, return_type='dataframe')
        viflist=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
        for index in range(len(viflist)):
    #         print(viflist[index],list(X.columns)[index])
            vif.loc[list(X.columns)[index],col]=viflist[index]
    print(vif)
# Out:
#                             CHELSA_ai_stand CHELSA_bio1_stand  \
# CHELSA_ai_stand                         NaN           1.13367
# CHELSA_bio1_stand                  1.050533               NaN
# CHELSA_bio4_stand                  1.243735          1.186508
# CHELSA_bio15_stand                 1.205765          1.319692
# StemHeightBladeLength_stand        1.003569          1.008661
# Intercept                          1.020619          1.020724
#
#                             CHELSA_bio4_stand CHELSA_bio15_stand  \
# CHELSA_ai_stand                      1.176272           1.042989
# CHELSA_bio1_stand                    1.039857           1.057823
# CHELSA_bio4_stand                         NaN           1.042375
# CHELSA_bio15_stand                    1.13969                NaN
# StemHeightBladeLength_stand          1.007102            1.00804
# Intercept                            1.020692           1.020711
#
#                             StemHeightBladeLength_stand
# CHELSA_ai_stand                                1.175406
# CHELSA_bio1_stand                              1.094735
# CHELSA_bio4_stand                              1.247194
# CHELSA_bio15_stand                             1.364901
# StemHeightBladeLength_stand                         NaN
# Intercept                                           1.0
#                             CHELSA_ai_stand CHELSA_bio1_stand  \
# CHELSA_ai_stand                         NaN          1.157538
# CHELSA_bio1_stand                  1.021959               NaN
# CHELSA_bio12_stand                 1.075021          1.076428
# CHELSA_bio15_stand                 1.057631          1.205563
# StemHeightBladeLength_stand        1.005707          1.009763
# Intercept                          1.020663          1.020746
#
#                             CHELSA_bio12_stand CHELSA_bio15_stand  \
# CHELSA_ai_stand                       1.176272           1.042675
# CHELSA_bio1_stand                     1.039857           1.049307
# CHELSA_bio12_stand                         NaN           1.026858
# CHELSA_bio15_stand                     1.13969                NaN
# StemHeightBladeLength_stand           1.007102           1.009224
# Intercept                             1.020692           1.020735
#
#                             StemHeightBladeLength_stand
# CHELSA_ai_stand                                1.209464
# CHELSA_bio1_stand                              1.072109
# CHELSA_bio12_stand                             1.106889
# CHELSA_bio15_stand                             1.231104
# StemHeightBladeLength_stand                         NaN
# Intercept                                           1.0
#                        CHELSA_ai_stand CHELSA_bio1_stand CHELSA_bio4_stand  \
# CHELSA_ai_stand                    NaN          1.428022          1.429774
# CHELSA_bio1_stand             1.139213               NaN          1.059789
# CHELSA_bio4_stand             1.382444          1.284486               NaN
# CHELSA_bio15_stand            1.231163          1.321051          1.163657
# HeightOverCanopy_stand        1.163685          1.358585          1.277032
# Intercept                          1.0               1.0               1.0
#
#                        CHELSA_bio15_stand HeightOverCanopy_stand
# CHELSA_ai_stand                  1.297614               1.175406
# CHELSA_bio1_stand                1.110759               1.094735
# CHELSA_bio4_stand                1.185865               1.247194
# CHELSA_bio15_stand                    NaN               1.364901
# HeightOverCanopy_stand           1.424227                    NaN
# Intercept                             1.0                    1.0
#                        CHELSA_ai_stand CHELSA_bio1_stand CHELSA_bio12_stand  \
# CHELSA_ai_stand                    NaN          1.411835           1.429774
# CHELSA_bio1_stand              1.10334               NaN           1.059789
# CHELSA_bio12_stand            1.243802          1.179717                NaN
# CHELSA_bio15_stand            1.067266          1.212784           1.163657
# HeightOverCanopy_stand        1.213877          1.376878           1.277032
# Intercept                          1.0               1.0                1.0
#
#                        CHELSA_bio15_stand HeightOverCanopy_stand
# CHELSA_ai_stand                  1.236985               1.209464
# CHELSA_bio1_stand                1.098502               1.072109
# CHELSA_bio12_stand               1.173278               1.106889
# CHELSA_bio15_stand                    NaN               1.231104
# HeightOverCanopy_stand           1.432084                    NaN
# Intercept                             1.0                    1.0
#                           CHELSA_ai_stand CHELSA_bio1_stand CHELSA_bio4_stand  \
# CHELSA_ai_stand                       NaN          1.854023           1.79835
# CHELSA_bio1_stand                1.172462               NaN          1.114628
# CHELSA_bio4_stand                1.403196          1.375279               NaN
# CHELSA_bio15_stand               1.210414          1.331172          1.221773
# Max_Rachis_Length_m_stand        1.069744          1.088075          1.015268
# HeightOverCanopy_stand           1.261808          1.750355          1.647238
# Intercept                        1.017275          1.047182          1.052591
#
#                           CHELSA_bio15_stand Max_Rachis_Length_m_stand  \
# CHELSA_ai_stand                     1.648079                  1.823198
# CHELSA_bio1_stand                   1.146204                  1.172725
# CHELSA_bio4_stand                   1.298012                   1.35014
# CHELSA_bio15_stand                       NaN                  1.357552
# Max_Rachis_Length_m_stand           1.084543                       NaN
# HeightOverCanopy_stand              1.920621                  1.906891
# Intercept                           1.050487                  1.052163
#
#                           HeightOverCanopy_stand
# CHELSA_ai_stand                         1.215313
# CHELSA_bio1_stand                       1.066117
# CHELSA_bio4_stand                       1.237929
# CHELSA_bio15_stand                      1.358602
# Max_Rachis_Length_m_stand               1.077624
# HeightOverCanopy_stand                       NaN
# Intercept                               1.017685
#                           CHELSA_ai_stand CHELSA_bio1_stand  \
# CHELSA_ai_stand                       NaN           1.80637
# CHELSA_bio1_stand                1.154756               NaN
# CHELSA_bio12_stand                1.37855          1.336579
# CHELSA_bio15_stand               1.089804           1.26683
# Max_Rachis_Length_m_stand        1.083705          1.095249
# HeightOverCanopy_stand           1.350649          1.778027
# Intercept                        1.017957          1.048818
#
#                           CHELSA_bio12_stand CHELSA_bio15_stand  \
# CHELSA_ai_stand                      1.79835           1.530168
# CHELSA_bio1_stand                   1.114628           1.137085
# CHELSA_bio12_stand                       NaN           1.315011
# CHELSA_bio15_stand                  1.221773                NaN
# Max_Rachis_Length_m_stand           1.015268           1.094246
# HeightOverCanopy_stand              1.647238           1.926205
# Intercept                           1.052591           1.050674
#
#                           Max_Rachis_Length_m_stand HeightOverCanopy_stand
# CHELSA_ai_stand                            1.786928               1.256553
# CHELSA_bio1_stand                          1.154496               1.057452
# CHELSA_bio12_stand                          1.28329               1.174743
# CHELSA_bio15_stand                         1.285051               1.276292
# Max_Rachis_Length_m_stand                       NaN               1.083377
# HeightOverCanopy_stand                     1.920158                    NaN
# Intercept                                  1.053383               1.023032

# %%
vif[vif['testing_var']=='CHELSA_bio1_stand']

fig,ax=plt.subplots(figsize=(10,10),facecolor='w')

hm=sns.heatmap(vif,cmap='viridis',linewidths=1,linecolor='white',xticklabels=vif.columns,yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
           annot=True,fmt='.1f',annot_kws={'fontsize':15,'color':'#e3e3e3','fontweight':'bold'})
sns.heatmap(all_rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=allvariable_dict.values(),yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
           annot=True,mask=all_rho<0.6,fmt='.1f',annot_kws={'fontsize':15,'color':'#787878','fontweight':'bold'})

hm.set_xticklabels(hm.get_xticklabels(), rotation=90,fontdict={'fontsize':18,'verticalalignment':'top'}) #horizontalalignment
hm.set_yticklabels(hm.get_yticklabels(), rotation=0,fontdict={'fontsize':18,'verticalalignment':'center'}) #[ 'center' | 'top' | 'bottom' | 'baseline' ]

# plt.savefig('./Cor_allvariables.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
#         vif                   correlates        testing_var
# 0  1.367767                    Intercept  CHELSA_bio1_stand
# 1  1.909900              CHELSA_ai_stand  CHELSA_bio1_stand
# 2  2.424591  StemHeightBladeLength_stand  CHELSA_bio1_stand
# 3  2.420277    Max_Rachis_Length_m_stand  CHELSA_bio1_stand
# 4  1.869419       HeightOverCanopy_stand  CHELSA_bio1_stand
# 5  3.759367            CHELSA_bio4_stand  CHELSA_bio1_stand
# 6  3.646927           CHELSA_bio12_stand  CHELSA_bio1_stand
# 7  1.339955           CHELSA_bio15_stand  CHELSA_bio1_stand

# %% [raw]
# Fig,ax=plt.subplots(figsize=(8,8),facecolor='w')
# hm=sns.heatmap(rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=allvariable_dict.values(),yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
#            annot=True,fmt='.1f',annot_kws={'fontsize':15,'color':'#e3e3e3','fontweight':'bold'})
# sns.heatmap(rho,cmap='viridis',linewidths=1,linecolor='white',xticklabels=allvariable_dict.values(),yticklabels=allvariable_dict.values(),ax=ax,cbar=False,
#            annot=True,mask=rho<0.6,fmt='.1f',annot_kws={'fontsize':15,'color':'#787878','fontweight':'bold'})
# hm.set_xticklabels(hm.get_xticklabels(), rotation=90,fontdict={'fontsize':18,'verticalalignment':'top'}) #horizontalalignment
# hm.set_yticklabels(hm.get_yticklabels(), rotation=0,fontdict={'fontsize':18,'verticalalignment':'center'}) #[ 'center' | 'top' | 'bottom' | 'baseline' ]
# plt.savefig('./Cor_selectedvariables.pdf',dpi=300,bbox_inches='tight')
# plt.show()

# %% [markdown]
# ### produce R scripts
