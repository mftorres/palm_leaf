# %%
import baltic as bt
import numpy as np
import pandas as pd
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from matplotlib import gridspec
import scipy.stats as stats
from scipy.stats import gaussian_kde
from matplotlib import rcParams 
# from matplotlib import style
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
import matplotlib.patheffects as path_effects

# %% [markdown]
# # 1. Basic leaf shape stats

# %%
palms=pd.read_csv('../data_files/palms_alltraits_curated_20220620.csv',sep='\t')
palms.groupby(by='shape').count()['species'].reset_index()
# Out:
#         shape  species
# 0   bipinnate       14
# 1  cospalmate      442
# 2      entire      105
# 3     pinnate     1298
# 4    variable      139

# %% [markdown]
# ## 1.1. Using the 2550 species phylogeny to quantify data

# %%
treeFileNexus='../data_files/Clean_1_1_MCCT_nexus.nex'
cc=bt.loadNexus(treeFileNexus,absoluteTime=False,tip_regex='_([0-9\-]+)$') ## treeFile here can alternatively be a path to a local file

cc.treeStats()
cc.drawTree()
cc.sortBranches()
cc.setAbsoluteTime(0)
# Out:
# Tree height: 108.328870
# Tree length: 18144.538310
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 5099 (2549 nodes and 2550 leaves)

# %%
# list of species in the tree:
sppintree=[k.name for k in cc.getExternal()]
print('Number of species in the tree: %s'%(len(sppintree)))

intree=palms[palms['tip_name'].isin(sppintree)]
print('Number of species remaining in the dataset: %s'%(len(intree)))
print('Number of species not considered in the stats*: %s'%(len(sppintree)-len(intree)))
print('*These are climbing species or species with no information (few)')
# Out:
# Number of species in the tree: 2550
# Number of species remaining in the dataset: 1978
# Number of species not considered in the stats*: 572
# *These are climbing species or species with no information (few)

# %%
shapeperc=intree.groupby(by='shape').count()['species'].reset_index().copy(deep=True)
shapeperc['percentage']=['%.2f'%(x) for x in (shapeperc['species']*100)/len(intree)]
shapeperc
# Out:
#         shape  species percentage
# 0   bipinnate       14       0.71
# 1  cospalmate      432      21.84
# 2      entire      105       5.31
# 3     pinnate     1288      65.12
# 4    variable      139       7.03

# %% [markdown]
# # 2. Within-species leaf shape variation

# %%
intree['shape'].unique()
intree[intree['shape']=='variable']
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  index  \
# 188            188           188           195         195    195
# 203            203           203           211         211    211
# 205            205           205           213         213    213
# 210            210           210           218         218    218
# 215            215           215           223         223    223
# ...            ...           ...           ...         ...    ...
# 1681          1681          1681          2351        2351    443
# 1723          1723          1723          2400        2400    492
# 1725          1725          1725          2402        2402    494
# 1728          1728          1728          2405        2405    497
# 1898          1898          1898          2600        2600    692
#
#                    species  coordinateUncertaintyInMeters  decimalLatitude  \
# 188   Bactris_acanthocarpa                          100.0        -3.950000
# 203    Bactris_coloradonis                         3615.0         8.631950
# 205     Bactris_corossilla                          100.0        -0.973717
# 210        Bactris_faucium                            NaN       -17.080000
# 215     Bactris_glandulosa                          437.0         8.790000
# ...                    ...                            ...              ...
# 1681    Hydriastele_boumae                            NaN              NaN
# 1723    Iguanura_piahensis                            NaN              NaN
# 1725   Iguanura_sanderiana                            NaN              NaN
# 1728  Iguanura_wallichiana                            NaN              NaN
# 1898        Pinanga_limosa                            NaN              NaN
#
#       decimalLongitude        gbifID  ...  CHELSA_vpd_min_stand  \
# 188         -68.847224  1.260222e+09  ...             -0.085226
# 203         -78.959858  1.260244e+09  ...             -0.784575
# 205         -73.830278  1.258443e+09  ...             -0.317656
# 210         -65.366660  1.259842e+09  ...              0.532956
# 215         -83.418789  1.259766e+09  ...             -0.467876
# ...                ...           ...  ...                   ...
# 1681               NaN           NaN  ...                   NaN
# 1723               NaN           NaN  ...                   NaN
# 1725               NaN           NaN  ...                   NaN
# 1728               NaN           NaN  ...                   NaN
# 1898               NaN           NaN  ...                   NaN
#
#       Simard_Pinto_3DGlobalVeg_JGR_stand  MaxStemHeight_m_stand  \
# 188                             1.639349              -0.411648
# 203                            -0.538311               0.792754
# 205                             2.024892               0.373776
# 210                            -0.538311               0.373776
# 215                            -0.538311               0.230882
# ...                                  ...                    ...
# 1681                                 NaN               1.811139
# 1723                                 NaN              -0.411648
# 1725                                 NaN              -0.580655
# 1728                                 NaN               0.061875
# 1898                                 NaN               0.061875
#
#       MaxStemDia_cm_stand  MaxLeafNumber_stand  Max_Blade_Length_m_stand  \
# 188             -0.088756             0.374731                  1.112888
# 203              0.019137            -1.219380                  0.881575
# 205             -0.519291            -0.734762                  0.634625
# 210             -1.154232            -0.347803                 -0.807886
# 215             -0.431984            -1.219380                  0.634625
# ...                   ...                  ...                       ...
# 1681             1.090952                  NaN                  0.836817
# 1723                  NaN                  NaN                 -0.205191
# 1725            -0.615804                  NaN                  0.063328
# 1728            -0.615804            -0.347803                  0.401210
# 1898            -1.358637            -0.025667                 -0.372279
#
#       Max_Rachis_Length_m_stand  Max_Petiole_length_m_stand  \
# 188                    0.319509                    1.810132
# 203                    0.319509                    1.059462
# 205                   -0.072151                   -0.748554
# 210                   -1.252286                   -0.748554
# 215                    0.058299                    0.872526
# ...                         ...                         ...
# 1681                   0.628320                    0.087606
# 1723                        NaN                   -0.748554
# 1725                  -0.164402                    0.087606
# 1728                   0.257511                   -0.748554
# 1898                        NaN                   -0.748554
#
#       StemHeightBladeLength_stand  HeightOverCanopy_stand
# 188                      0.274911               -1.572486
# 203                      0.816274                0.690442
# 205                      0.369627               -1.582306
# 210                      0.125445                0.618597
# 215                      0.361580                0.643807
# ...                           ...                     ...
# 1681                     1.647940                     NaN
# 1723                    -0.451160                     NaN
# 1725                    -0.384713                     NaN
# 1728                     0.079015                     NaN
# 1898                    -0.099943                     NaN
#
# [139 rows x 144 columns]

# %%
intree[intree['shape']=='variable'][['PalmSubfamily','PalmTribe','tip_name']].to_csv('../data_files/Polymorphic_species_20220706.csv',sep='\t')

# %% [markdown]
# # 3. Percentage of annotated species per variable

# %%
list(intree.columns)
annotated=intree[[x for x in intree.columns if 'stand' in x]].describe().T['count'].reset_index().copy(deep=True)
annotated['percent']=['%.2f'%(s) for s in annotated['count']*100/len(intree)]
annotated
# Out:
#                                  index   count percent
# 0                      CHELSA_ai_stand  1508.0   76.24
# 1                   CHELSA_bio10_stand  1508.0   76.24
# 2                   CHELSA_bio11_stand  1508.0   76.24
# 3                   CHELSA_bio12_stand  1508.0   76.24
# 4                   CHELSA_bio13_stand  1508.0   76.24
# 5                   CHELSA_bio14_stand  1508.0   76.24
# 6                   CHELSA_bio15_stand  1508.0   76.24
# 7                   CHELSA_bio16_stand  1508.0   76.24
# 8                   CHELSA_bio17_stand  1508.0   76.24
# 9                   CHELSA_bio18_stand  1508.0   76.24
# 10                  CHELSA_bio19_stand  1508.0   76.24
# 11                   CHELSA_bio1_stand  1508.0   76.24
# 12                   CHELSA_bio2_stand  1508.0   76.24
# 13                   CHELSA_bio3_stand  1508.0   76.24
# 14                   CHELSA_bio4_stand  1508.0   76.24
# 15                   CHELSA_bio5_stand  1508.0   76.24
# 16                   CHELSA_bio6_stand  1508.0   76.24
# 17                   CHELSA_bio7_stand  1508.0   76.24
# 18                   CHELSA_bio8_stand  1508.0   76.24
# 19                   CHELSA_bio9_stand  1508.0   76.24
# 20                CHELSA_cmi_max_stand  1508.0   76.24
# 21               CHELSA_cmi_mean_stand  1508.0   76.24
# 22                CHELSA_cmi_min_stand  1508.0   76.24
# 23              CHELSA_cmi_range_stand  1508.0   76.24
# 24                    CHELSA_fcf_stand  1508.0   76.24
# 25                   CHELSA_gdd0_stand  1508.0   76.24
# 26                CHELSA_gdgfgd0_stand  1508.0   76.24
# 27                    CHELSA_gsl_stand  1508.0   76.24
# 28                    CHELSA_gst_stand  1508.0   76.24
# 29               CHELSA_hurs_max_stand  1508.0   76.24
# 30               CHELSA_hurs_min_stand  1508.0   76.24
# 31             CHELSA_hurs_range_stand  1508.0   76.24
# 32                    CHELSA_lgd_stand  1508.0   76.24
# 33                   CHELSA_ngd0_stand  1508.0   76.24
# 34                    CHELSA_npp_stand  1508.0   76.24
# 35                CHELSA_vpd_max_stand  1508.0   76.24
# 36               CHELSA_vpd_mean_stand  1508.0   76.24
# 37                CHELSA_vpd_min_stand  1508.0   76.24
# 38  Simard_Pinto_3DGlobalVeg_JGR_stand  1508.0   76.24
# 39               MaxStemHeight_m_stand  1978.0  100.00
# 40                 MaxStemDia_cm_stand  1554.0   78.56
# 41                 MaxLeafNumber_stand  1284.0   64.91
# 42            Max_Blade_Length_m_stand  1978.0  100.00
# 43           Max_Rachis_Length_m_stand  1213.0   61.32
# 44          Max_Petiole_length_m_stand  1978.0  100.00
# 45         StemHeightBladeLength_stand  1978.0  100.00
# 46              HeightOverCanopy_stand  1508.0   76.24

# %%
annotated.to_csv('../data_files/variables_sppannotated_20220620.txt',sep='\t')

# %% [markdown]
# # 4. Number of climbing species

# %%
# list made in the 02_Variables_database notebook
climbing=pd.read_csv('../data_files/climbing_spp_20220620.txt',sep='\t')
# before filtering out species not in the Faurby et al. (2016) tree
climbing.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0        index  coordinateUncertaintyInMeters  \
# count    722.000000   722.000000   722.000000                     113.000000
# mean    1369.404432  1369.404432   518.468144                    2080.159867
# std      801.189738   801.189738   402.691788                    7761.648856
# min       14.000000    14.000000     4.000000                       0.010000
# 25%      530.250000   530.250000   240.000000                       1.000000
# 50%     1335.000000  1335.000000   430.500000                       5.000000
# 75%     2115.750000  2115.750000   605.000000                     301.000000
# max     2716.000000  2716.000000  1891.000000                   65886.000000
#
#        decimalLatitude  decimalLongitude        gbifID  individualCount  \
# count       400.000000        400.000000  4.000000e+02        78.000000
# mean          3.103748         85.773303  1.532262e+09         1.916667
# std           9.891852         64.276672  7.199983e+08         1.531947
# min         -29.368611        -96.033315  9.412378e+07         1.000000
# 25%          -1.416250         98.152950  9.124301e+08         1.000000
# 50%           3.943330        109.569942  1.420575e+09         1.000000
# 75%           8.829722        118.708834  1.993734e+09         2.500000
# max          27.206512        153.193425  3.462293e+09        10.000000
#
#               year     CHELSA_ai  ...    Climbing  Acaulescent  \
# count   391.000000    400.000000  ...  525.000000   525.000000
# mean   1980.337596 -79998.931250  ...    1.028571     0.007619
# std      31.932278  39578.102259  ...    0.166758     0.123325
# min    1845.000000 -99999.000000  ...    1.000000     0.000000
# 25%    1974.750000 -99999.000000  ...    1.000000     0.000000
# 50%    1987.000000 -99999.000000  ...    1.000000     0.000000
# 75%    2002.000000 -99999.000000  ...    1.000000     0.000000
# max    2020.000000      3.135691  ...    2.000000     2.000000
#
#        MaxStemHeight_m  MaxStemDia_cm  MaxLeafNumber  Max_Blade_Length_m  \
# count       722.000000     377.000000            0.0          722.000000
# mean         12.122576       3.497215            NaN            0.866891
# std          19.141451       5.273225            NaN            1.240022
# min           0.000000       0.300000            NaN            0.000000
# 25%           0.000000       1.300000            NaN            0.000000
# 50%           0.000000       2.200000            NaN            0.000000
# 75%          20.000000       4.000000            NaN            1.500000
# max         170.000000      70.000000            NaN            7.000000
#
#        Max_Rachis_Length_m  Max_Petiole_length_m  StemHeightBladeLength  \
# count           296.000000            722.000000                  197.0
# mean              1.620304              0.058289                    0.0
# std               1.132431              0.186288                    0.0
# min               0.190000              0.000000                    0.0
# 25%               0.800000              0.000000                    0.0
# 50%               1.300000              0.000000                    0.0
# 75%               2.162500              0.000000                    0.0
# max               6.400000              2.100000                    0.0
#
#        HeightOverCanopy
# count      4.000000e+02
# mean       1.306860e+11
# std        2.079405e+11
# min        0.000000e+00
# 25%        0.000000e+00
# 50%        4.110000e+00
# 75%        2.143250e+11
# max        1.534000e+12
#
# [8 rows x 70 columns]

# %%
# list of species in the tree:
sppintree=[k.name for k in cc.getExternal()]
print('Number of species in the tree: %s'%(len(sppintree)))

climbintree=climbing[climbing['tip_name'].isin(sppintree)]
print('Number of Climbing species in the tree: %s'%(len(climbintree)))
# Out:
# Number of species in the tree: 2550
# Number of Climbing species in the tree: 572

# %%
climbintree[['PalmSubfamily','PalmTribe','tip_name']].to_csv('../data_files/Climbingintree_species_20220706.csv',sep='\t')
