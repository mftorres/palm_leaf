# %%
import baltic as bt
import numpy as np
import pandas as pd
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from matplotlib import gridspec
import scipy.stats as stats
from scipy.stats import gaussian_kde
from matplotlib import rcParams 
# from matplotlib import style
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
import matplotlib.patheffects as path_effects

# %% [markdown]
# # 1. Basic leaf shape stats

# %%
palms=pd.read_csv('../data_files/palms_alltraits_curated_20220620.csv',sep='\t')
palms.groupby(by='shape').count()['species'].reset_index()
# Out:
#         shape  species
# 0   bipinnate       16
# 1  cospalmate      455
# 2      entire      108
# 3     pinnate     1405
# 4    variable      140

# %% [markdown]
# ## 1.1. Using the 2550 species phylogeny to quantify data

# %%
treeFileNexus='../data_files/Clean_1_1_MCCT_nexus.nex'
cc=bt.loadNexus(treeFileNexus,absoluteTime=False,tip_regex='_([0-9\-]+)$') ## treeFile here can alternatively be a path to a local file

cc.treeStats()
cc.drawTree()
cc.sortBranches()
cc.setAbsoluteTime(0)
# Out:
# Tree height: 108.328870
# Tree length: 18144.538310
# strictly bifurcating tree
# annotations present
#
# Numbers of objects in tree: 5099 (2549 nodes and 2550 leaves)

# %%
# list of species in the tree:
sppintree=[k.name for k in cc.getExternal()]
print('Number of species in the tree: %s'%(len(sppintree)))

intree=palms[palms['tip_name'].isin(sppintree)]
print('Number of species remaining in the dataset: %s'%(len(intree)))
print('Number of species not considered in the stats*: %s'%(len(sppintree)-len(intree)))
print('*These are climbing species or species with no information (few)')
# Out:
# Number of species in the tree: 2550
# Number of species remaining in the dataset: 2071
# Number of species not considered in the stats*: 479
# *These are climbing species or species with no information (few)

# %%
intree['CHELSA_bio1'].dropna()
# Out:
# 0       2.306425
# 1       2.226600
# 2       2.407391
# 3       2.422426
# 4       2.410777
#           ...
# 1588    2.021189
# 1589    2.054996
# 1590    2.141450
# 1591    2.435367
# 1592    2.202761
# Name: CHELSA_bio1, Length: 1570, dtype: float64

# %%
shapeperc=intree.groupby(by='shape').count()['species'].reset_index().copy(deep=True)
shapeperc['percentage']=['%.2f'%(x) for x in (shapeperc['species']*100)/len(intree)]
shapeperc
# Out:
#         shape  species percentage
# 0   bipinnate       14       0.68
# 1  cospalmate      440      21.25
# 2      entire      106       5.12
# 3     pinnate     1370      66.15
# 4    variable      140       6.76

# %% [markdown]
# # 2. Within-species leaf shape variation

# %%
intree['shape'].unique()
intree[intree['shape']=='variable']
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  index               species  \
# 195            195           195         195    195  Bactris_acanthocarpa
# 211            211           211         211    211   Bactris_coloradonis
# 213            213           213         213    213    Bactris_corossilla
# 218            218           218         218    218       Bactris_faucium
# 223            223           223         223    223    Bactris_glandulosa
# ...            ...           ...         ...    ...                   ...
# 1842          1842          2351        2351    443    Hydriastele_boumae
# 1891          1891          2400        2400    492    Iguanura_piahensis
# 1893          1893          2402        2402    494   Iguanura_sanderiana
# 1896          1896          2405        2405    497  Iguanura_wallichiana
# 2082          2082          2600        2600    692        Pinanga_limosa
#
#       coordinateUncertaintyInMeters  decimalLatitude  decimalLongitude  \
# 195                           100.0        -3.950000        -68.847224
# 211                          3615.0         8.631950        -78.959858
# 213                           100.0        -0.973717        -73.830278
# 218                             NaN       -17.080000        -65.366660
# 223                           437.0         8.790000        -83.418789
# ...                             ...              ...               ...
# 1842                            NaN              NaN               NaN
# 1891                            NaN              NaN               NaN
# 1893                            NaN              NaN               NaN
# 1896                            NaN              NaN               NaN
# 2082                            NaN              NaN               NaN
#
#             gbifID  individualCount  ...  CHELSA_vpd_min_stand  \
# 195   1.260222e+09              1.0  ...             -0.098457
# 211   1.260244e+09              1.0  ...             -0.794410
# 213   1.258443e+09              1.0  ...             -0.329758
# 218   1.259842e+09              1.0  ...              0.516724
# 223   1.259766e+09              2.0  ...             -0.479248
# ...            ...              ...  ...                   ...
# 1842           NaN              NaN  ...                   NaN
# 1891           NaN              NaN  ...                   NaN
# 1893           NaN              NaN  ...                   NaN
# 1896           NaN              NaN  ...                   NaN
# 2082           NaN              NaN  ...                   NaN
#
#       Simard_Pinto_3DGlobalVeg_JGR_stand  MaxStemHeight_m_stand  \
# 195                             1.646933              -0.272948
# 211                            -0.536819               0.887431
# 213                             2.033555               0.483767
# 218                            -0.536819               0.483767
# 223                            -0.536819               0.346096
# ...                                  ...                    ...
# 1842                                 NaN               1.868593
# 1891                                 NaN              -0.272948
# 1893                                 NaN              -0.435778
# 1896                                 NaN               0.183266
# 2082                                 NaN               0.183266
#
#       MaxStemDia_cm_stand  MaxLeafNumber_stand  Max_Blade_Length_m_stand  \
# 195             -0.088756             0.374731                  1.202122
# 211              0.019137            -1.219380                  0.975348
# 213             -0.519291            -0.734762                  0.733242
# 218             -1.154232            -0.347803                 -0.680968
# 223             -0.431984            -1.219380                  0.733242
# ...                   ...                  ...                       ...
# 1842             1.090952                  NaN                  0.931468
# 1891                  NaN                  NaN                 -0.090097
# 1893            -0.615804                  NaN                  0.173153
# 1896            -0.615804            -0.347803                  0.504407
# 2082            -1.358637            -0.025667                 -0.253907
#
#       Max_Rachis_Length_m_stand  Max_Petiole_length_m_stand  \
# 195                    0.319509                    1.920003
# 211                    0.319509                    1.152264
# 213                   -0.072151                   -0.696866
# 218                   -1.252286                   -0.696866
# 223                    0.058299                    0.961077
# ...                         ...                         ...
# 1842                   0.628320                    0.158308
# 1891                        NaN                   -0.696866
# 1893                  -0.164402                    0.158308
# 1896                   0.257511                   -0.696866
# 2082                        NaN                   -0.696866
#
#       StemHeightBladeLength_stand  HeightOverCanopy_stand
# 195                      0.401766               -1.433035
# 211                      0.902899                0.747914
# 213                      0.489443               -1.442500
# 218                      0.263407                0.678671
# 223                      0.481993                0.702968
# ...                           ...                     ...
# 1842                     1.672763                     NaN
# 1891                    -0.270351                     NaN
# 1893                    -0.208842                     NaN
# 1896                     0.220426                     NaN
# 2082                     0.054767                     NaN
#
# [140 rows x 143 columns]

# %%
intree[intree['shape']=='variable'][['PalmSubfamily','PalmTribe','tip_name']].to_csv('../data_files/Polymorphic_species_20220706.csv',sep='\t')

# %% [markdown]
# # 3. Percentage of annotated species per variable

# %%
list(intree.columns)
annotated=intree[[x for x in intree.columns if 'stand' in x]].describe().T['count'].reset_index().copy(deep=True)
annotated['percent']=['%.2f'%(s) for s in annotated['count']*100/len(intree)]
annotated
# Out:
#                                  index   count percent
# 0                      CHELSA_ai_stand  1570.0   75.81
# 1                   CHELSA_bio10_stand  1570.0   75.81
# 2                   CHELSA_bio11_stand  1570.0   75.81
# 3                   CHELSA_bio12_stand  1570.0   75.81
# 4                   CHELSA_bio13_stand  1570.0   75.81
# 5                   CHELSA_bio14_stand  1570.0   75.81
# 6                   CHELSA_bio15_stand  1570.0   75.81
# 7                   CHELSA_bio16_stand  1570.0   75.81
# 8                   CHELSA_bio17_stand  1570.0   75.81
# 9                   CHELSA_bio18_stand  1570.0   75.81
# 10                  CHELSA_bio19_stand  1570.0   75.81
# 11                   CHELSA_bio1_stand  1570.0   75.81
# 12                   CHELSA_bio2_stand  1570.0   75.81
# 13                   CHELSA_bio3_stand  1570.0   75.81
# 14                   CHELSA_bio4_stand  1570.0   75.81
# 15                   CHELSA_bio5_stand  1570.0   75.81
# 16                   CHELSA_bio6_stand  1570.0   75.81
# 17                   CHELSA_bio7_stand  1570.0   75.81
# 18                   CHELSA_bio8_stand  1570.0   75.81
# 19                   CHELSA_bio9_stand  1570.0   75.81
# 20                CHELSA_cmi_max_stand  1570.0   75.81
# 21               CHELSA_cmi_mean_stand  1570.0   75.81
# 22                CHELSA_cmi_min_stand  1570.0   75.81
# 23              CHELSA_cmi_range_stand  1570.0   75.81
# 24                    CHELSA_fcf_stand  1570.0   75.81
# 25                   CHELSA_gdd0_stand  1570.0   75.81
# 26                CHELSA_gdgfgd0_stand  1570.0   75.81
# 27                    CHELSA_gsl_stand  1570.0   75.81
# 28                    CHELSA_gst_stand  1570.0   75.81
# 29               CHELSA_hurs_max_stand  1570.0   75.81
# 30               CHELSA_hurs_min_stand  1570.0   75.81
# 31             CHELSA_hurs_range_stand  1570.0   75.81
# 32                    CHELSA_lgd_stand  1570.0   75.81
# 33                   CHELSA_ngd0_stand  1570.0   75.81
# 34                    CHELSA_npp_stand  1570.0   75.81
# 35                CHELSA_vpd_max_stand  1570.0   75.81
# 36               CHELSA_vpd_mean_stand  1570.0   75.81
# 37                CHELSA_vpd_min_stand  1570.0   75.81
# 38  Simard_Pinto_3DGlobalVeg_JGR_stand  1570.0   75.81
# 39               MaxStemHeight_m_stand  2071.0  100.00
# 40                 MaxStemDia_cm_stand  1554.0   75.04
# 41                 MaxLeafNumber_stand  1284.0   62.00
# 42            Max_Blade_Length_m_stand  2071.0  100.00
# 43           Max_Rachis_Length_m_stand  1213.0   58.57
# 44          Max_Petiole_length_m_stand  2071.0  100.00
# 45         StemHeightBladeLength_stand  2071.0  100.00
# 46              HeightOverCanopy_stand  1570.0   75.81

# %%
# annotated.to_csv('../data_files/variables_sppannotated_20220620.txt',sep='\t')

# %% [markdown]
# # 4. Number of climbing species

# %%
# list made in the 02_Variables_database notebook
climbing=pd.read_csv('../data_files/climbing_spp_20220620.txt',sep='\t')
# before filtering out species not in the Faurby et al. (2016) tree
climbing.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0        index  coordinateUncertaintyInMeters  \
# count    525.000000   525.000000   525.000000                      91.000000
# mean    1266.619048  1266.619048   503.419048                    2169.265824
# std      770.521881   770.521881   360.325150                    8006.350905
# min      337.000000   337.000000    79.000000                       0.010000
# 25%      515.000000   515.000000   248.000000                       1.000000
# 50%     1102.000000  1102.000000   428.000000                      15.500000
# 75%     2088.000000  2088.000000   596.000000                     446.500000
# max     2640.000000  2640.000000  1618.000000                   65886.000000
#
#        decimalLatitude  decimalLongitude        gbifID  individualCount  \
# count       315.000000        315.000000  3.150000e+02        52.000000
# mean          4.229816         93.452297  1.452608e+09         1.980769
# std           8.840948         57.409357  7.005438e+08         1.734770
# min         -28.583697        -96.033315  9.412378e+07         1.000000
# 25%          -0.720695        101.110750  9.124097e+08         1.000000
# 50%           4.181667        113.833333  1.258627e+09         1.000000
# 75%           9.120818        120.210000  1.930579e+09         2.000000
# max          27.206512        153.193425  3.032113e+09        10.000000
#
#               year     CHELSA_ai  ...    Climbing  Acaulescent  \
# count   307.000000    315.000000  ...  525.000000   525.000000
# mean   1975.923453 -80951.303119  ...    1.028571     0.007619
# std      31.874957  38923.325672  ...    0.166758     0.123325
# min    1845.000000 -99999.000000  ...    1.000000     0.000000
# 25%    1972.500000 -99999.000000  ...    1.000000     0.000000
# 50%    1982.000000 -99999.000000  ...    1.000000     0.000000
# 75%    1997.000000 -99999.000000  ...    1.000000     0.000000
# max    2020.000000      3.135691  ...    2.000000     2.000000
#
#        MaxStemHeight_m  MaxStemDia_cm  MaxLeafNumber  Max_Blade_Length_m  \
# count       525.000000     377.000000            0.0          525.000000
# mean         16.671429       3.497215            NaN            1.192181
# std          20.692084       5.273225            NaN            1.314228
# min           0.000000       0.300000            NaN            0.000000
# 25%           0.000000       1.300000            NaN            0.000000
# 50%          10.000000       2.200000            NaN            0.900000
# 75%          25.000000       4.000000            NaN            2.000000
# max         170.000000      70.000000            NaN            7.000000
#
#        Max_Rachis_Length_m  Max_Petiole_length_m  StemHeightBladeLength  \
# count           296.000000            525.000000                    0.0
# mean              1.620304              0.080162                    NaN
# std               1.132431              0.214460                    NaN
# min               0.190000              0.000000                    NaN
# 25%               0.800000              0.000000                    NaN
# 50%               1.300000              0.000000                    NaN
# 75%               2.162500              0.000000                    NaN
# max               6.400000              2.100000                    NaN
#
#        HeightOverCanopy
# count      3.150000e+02
# mean       1.659505e+11
# std        2.215250e+11
# min        0.000000e+00
# 25%        6.010345e-01
# 50%        1.003000e+11
# 75%        2.617000e+11
# max        1.534000e+12
#
# [8 rows x 70 columns]

# %%
# list of species in the tree:
sppintree=[k.name for k in cc.getExternal()]
print('Number of species in the tree: %s'%(len(sppintree)))

climbintree=climbing[climbing['tip_name'].isin(sppintree)]
print('Number of Climbing species in the tree: %s'%(len(climbintree)))
# Out:
# Number of species in the tree: 2550
# Number of Climbing species in the tree: 479

# %%
climbintree[['PalmSubfamily','PalmTribe','tip_name']].to_csv('../data_files/Climbingintree_species_20220706.csv',sep='\t')

# %% [markdown]
# ## 5. Distribution of species medians by variable

# %%
variables=['CHELSA_ai','CHELSA_bio1','CHELSA_bio4','CHELSA_bio12','CHELSA_bio15',
           'Max_Rachis_Length_m','StemHeightBladeLength','HeightOverCanopy']

intree.groupby(by='shape')[variables].min().apply(lambda x: 10**x).reset_index()
# Out:
#         shape  CHELSA_ai  CHELSA_bio1  CHELSA_bio4  CHELSA_bio12  \
# 0   bipinnate        1.0        186.5        181.0        3403.0
# 1  cospalmate        1.0         44.5        109.0          96.0
# 2      entire        1.0         39.0         84.0         161.0
# 3     pinnate        1.0         18.0         92.0          12.0
# 4    variable        1.0         22.0        136.5         145.0
#
#    CHELSA_bio15  Max_Rachis_Length_m  StemHeightBladeLength  HeightOverCanopy
# 0         141.5                 5.50                    1.0      8.000000e+10
# 1         108.0                 1.29                    1.0      1.000000e+00
# 2         111.5                 1.05                    1.0      1.000000e+00
# 3          96.0                 1.11                    1.0      1.000000e+00
# 4         106.0                 1.06                    1.0      1.000000e+00

# %%
intree.groupby(by='shape')[variables].max().apply(lambda x: 10**x).reset_index()
# Out:
#         shape      CHELSA_ai  CHELSA_bio1  CHELSA_bio4  CHELSA_bio12  \
# 0   bipinnate  100001.548709        272.0       4102.0       28172.5
# 1  cospalmate  100003.433253        274.5       5608.5       44539.0
# 2      entire  100002.855431        284.5       6536.5       35492.0
# 3     pinnate  100003.976216        287.5       6973.0       46257.0
# 4    variable  100002.408126        281.5       6484.0       32427.0
#
#    CHELSA_bio15  Max_Rachis_Length_m  StemHeightBladeLength  HeightOverCanopy
# 0        1115.0                  9.0                  47.00      4.600000e+11
# 1        1670.0                  8.0                  48.75      4.710000e+11
# 2        1263.0                  5.5                  28.80      2.000000e+11
# 3        1382.5                 19.5                  69.12      5.820000e+11
# 4        1240.0                 16.0                  36.40      1.934000e+11

# %%
intree.groupby(by='shape')[variables].median().apply(lambda x: 10**x).reset_index()
# Out:
#         shape      CHELSA_ai  CHELSA_bio1  CHELSA_bio4  CHELSA_bio12  \
# 0   bipinnate       1.000000   250.959658  1365.191562   7008.107341
# 1  cospalmate       1.000000   211.500000  1474.000000   8227.000000
# 2      entire       1.000000   246.500000  1514.000000   2940.000000
# 3     pinnate       1.000000   257.000000   750.491839  12194.983600
# 4    variable  100000.025091   252.500000   836.000000  12243.000000
#
#    CHELSA_bio15  Max_Rachis_Length_m  StemHeightBladeLength  HeightOverCanopy
# 0    623.247543             7.000000              28.622544      2.827366e+11
# 1    405.000000             2.400000               7.000000      7.000000e+10
# 2    521.000000             1.329962               3.819987      1.350000e+10
# 3    518.499759             2.900000               7.389993      4.064997e+10
# 4    481.500000             1.550000               4.614997      1.750000e+10

# %%
# tallest entire species
intree[intree['shape']=='entire'][['tip_name','StemHeightBladeLength']].sort_values(by='StemHeightBladeLength', ascending=False).reset_index()
# Out:
#      index                     tip_name  StemHeightBladeLength
# 0     2190     Verschaffeltia_splendida               1.459392
# 1     1137           Marojejya_darianii               1.322219
# 2     2031  Phoenicophorium_borsigianum               1.255273
# 3     1202          Pelagodoxa_henryana               1.231724
# 4     1468     Sclerosperma_profizianum               1.183270
# ..     ...                          ...                    ...
# 101   1845          Hydriastele_cariosa               0.000000
# 102     65                 Areca_dayung               0.000000
# 103   2076            Pinanga_jambusana               0.000000
# 104    209           Bactris_chocoensis               0.000000
# 105    246              Bactris_obovata               0.000000
#
# [106 rows x 3 columns]

# %%
list(intree.columns)
intree['dissect'].unique()
intree.groupby(by='dissect')[variables].median().apply(lambda x: 10**x).reset_index()
# Out:
#      dissect  CHELSA_ai  CHELSA_bio1  CHELSA_bio4  CHELSA_bio12  CHELSA_bio15  \
# 0  dissected        1.0    253.50000   838.999404  11954.749997    498.499749
# 1     entire        1.0    247.49798  1596.493658   2335.730828    540.481267
#
#    Max_Rachis_Length_m  StemHeightBladeLength  HeightOverCanopy
# 0                 2.60                   7.00      4.290000e+10
# 1                 1.32                   3.77      1.514001e+10

# %%
palmtrait_kissling=pd.read_csv('../data_files/PalmTraits_1.0.txt')
list(palmtrait_kissling.columns)
palmtrait_kissling[['SpecName','Max_Rachis_Length_m']].sort_values(by='Max_Rachis_Length_m',ascending=False).reset_index()
# Out:
#       index                  SpecName  Max_Rachis_Length_m
# 0      2296         Raphia_farinifera                 18.5
# 1       280          Bactris_killipii                 15.0
# 2      2311          Raphia_taedigera                 15.0
# 3      2313           Raphia_vinifera                 12.0
# 4      1957         Oenocarpus_bataua                 11.0
# ...     ...                       ...                  ...
# 2552   2517      Veitchia_subdisticha                  NaN
# 2553   2518        Veitchia_vitiensis                  NaN
# 2554   2520  Verschaffeltia_splendida                  NaN
# 2555   2527            Wallichia_nana                  NaN
# 2556   2528    Wallichia_oblongifolia                  NaN
#
# [2557 rows x 3 columns]

# %%
palmtrait_kissling.columns
palmtrait_kissling['MaxStemHeight_m'].max()
# Out:
# 170.0

# %%
list(intree.columns)
intree[['StemHeightBladeLength','Simard_Pinto_3DGlobalVeg_JGR','HeightOverCanopy']].sort_values(by='HeightOverCanopy',ascending=False).reset_index()
# Out:
#       index  StemHeightBladeLength  Simard_Pinto_3DGlobalVeg_JGR  \
# 0       964               1.772322                           0.0
# 1       156               1.708421                           0.0
# 2      1460               1.682145                           0.0
# 3      1361               1.677151                           0.0
# 4       463               1.672098                           0.0
# ...     ...                    ...                           ...
# 2066   2190               1.459392                           NaN
# 2067   2191               0.000000                           NaN
# 2068   2192               0.841985                           NaN
# 2069   2193               0.812913                           NaN
# 2070   2194               1.287578                           NaN
#
#       HeightOverCanopy
# 0            11.764923
# 1            11.699838
# 2            11.673021
# 3            11.667920
# 4            11.662758
# ...                ...
# 2066               NaN
# 2067               NaN
# 2068               NaN
# 2069               NaN
# 2070               NaN
#
# [2071 rows x 4 columns]

# %%
intree[['StemHeightBladeLength','Simard_Pinto_3DGlobalVeg_JGR','HeightOverCanopy']][:10].apply(lambda x: 10**x).sort_values(by='HeightOverCanopy',ascending=False).reset_index()
# Out:
#    index  StemHeightBladeLength  Simard_Pinto_3DGlobalVeg_JGR  \
# 0      1                  22.65                           1.0
# 1      0                  16.50                           1.0
# 2      6                  16.00                           1.0
# 3      8                  13.65                           1.0
# 4      9                  11.42                           1.0
# 5      4                   2.41                           1.0
# 6      2                   1.00                           1.0
# 7      3                   1.00                           1.0
# 8      5                   1.00                           1.0
# 9      7                   1.00                           1.0
#
#    HeightOverCanopy
# 0      2.165000e+11
# 1      1.550000e+11
# 2      1.500000e+11
# 3      1.265000e+11
# 4      1.042000e+11
# 5      1.410000e+10
# 6      1.000000e+00
# 7      1.000000e+00
# 8      1.000000e+00
# 9      1.000000e+00

# %%
# # summary=intree.groupby(by='shape')[variables].median().apply(lambda x: 10**x).reset_index().rename(mapper, axis=1).copy(deep=True)
mapper=dict(zip([x for x in variables],['%s_median'%(x) for x in variables]))
summarymedian=intree.groupby(by='shape')[variables].median().apply(lambda x: 10**x).rename(mapper, axis=1)#.copy(deep=True)
mapper=dict(zip([x for x in variables],['%s_min'%(x) for x in variables]))
summarymin=intree.groupby(by='shape')[variables].min().apply(lambda x: 10**x).rename(mapper, axis=1)#.reset_index()#.copy(deep=True)
mapper=dict(zip([x for x in variables],['%s_max'%(x) for x in variables]))
summarymax=intree.groupby(by='shape')[variables].max().apply(lambda x: 10**x).rename(mapper, axis=1)#.reset_index()#.copy(deep=True)
summary=pd.concat([summarymin,summarymedian,summarymax],axis=1,sort=True)

for col in variables:
    summary.loc[summary.index,'%s_range'%(col)]=summary['%s_max'%(col)]-summary['%s_min'%(col)]
# summary.T.astype('int').to_csv('../data_files/variable_summary-by_shape_20220822.csv',sep='\t')
summary.T.astype('int')
# Out:
# shape                            bipinnate    cospalmate        entire  \
# CHELSA_ai_min                            1             1             1
# CHELSA_bio1_min                        186            44            38
# CHELSA_bio4_min                        181           109            83
# CHELSA_bio12_min                      3402            96           160
# CHELSA_bio15_min                       141           108           111
# Max_Rachis_Length_m_min                  5             1             1
# StemHeightBladeLength_min                1             1             1
# HeightOverCanopy_min           80000000001             1             1
# CHELSA_ai_median                         1             1             1
# CHELSA_bio1_median                     250           211           246
# CHELSA_bio4_median                    1365          1473          1514
# CHELSA_bio12_median                   7008          8226          2939
# CHELSA_bio15_median                    623           405           521
# Max_Rachis_Length_m_median               7             2             1
# StemHeightBladeLength_median            28             7             3
# HeightOverCanopy_median       282736626563   70000000001   13500000001
# CHELSA_ai_max                       100001        100003        100002
# CHELSA_bio1_max                        272           274           284
# CHELSA_bio4_max                       4101          5608          6536
# CHELSA_bio12_max                     28172         44538         35491
# CHELSA_bio15_max                      1114          1670          1263
# Max_Rachis_Length_m_max                  8             8             5
# StemHeightBladeLength_max               47            48            28
# HeightOverCanopy_max          460000000000  471000000000  200000000000
# CHELSA_ai_range                     100000        100002        100001
# CHELSA_bio1_range                       85           229           245
# CHELSA_bio4_range                     3920          5499          6452
# CHELSA_bio12_range                   24769         44442         35330
# CHELSA_bio15_range                     973          1562          1151
# Max_Rachis_Length_m_range                3             6             4
# StemHeightBladeLength_range             46            47            27
# HeightOverCanopy_range        379999999999  470999999999  199999999999
#
# shape                              pinnate      variable
# CHELSA_ai_min                            1             1
# CHELSA_bio1_min                         17            21
# CHELSA_bio4_min                         92           136
# CHELSA_bio12_min                        12           144
# CHELSA_bio15_min                        96           106
# Max_Rachis_Length_m_min                  1             1
# StemHeightBladeLength_min                1             1
# HeightOverCanopy_min                     1             1
# CHELSA_ai_median                         1        100000
# CHELSA_bio1_median                     257           252
# CHELSA_bio4_median                     750           835
# CHELSA_bio12_median                  12194         12242
# CHELSA_bio15_median                    518           481
# Max_Rachis_Length_m_median               2             1
# StemHeightBladeLength_median             7             4
# HeightOverCanopy_median        40649969250   17500000001
# CHELSA_ai_max                       100003        100002
# CHELSA_bio1_max                        287           281
# CHELSA_bio4_max                       6972          6483
# CHELSA_bio12_max                     46257         32427
# CHELSA_bio15_max                      1382          1240
# Max_Rachis_Length_m_max                 19            16
# StemHeightBladeLength_max               69            36
# HeightOverCanopy_max          582000000001  193400000001
# CHELSA_ai_range                     100002        100001
# CHELSA_bio1_range                      269           259
# CHELSA_bio4_range                     6880          6347
# CHELSA_bio12_range                   46245         32282
# CHELSA_bio15_range                    1286          1134
# Max_Rachis_Length_m_range               18            14
# StemHeightBladeLength_range             68            35
# HeightOverCanopy_range        582000000000  193400000000
